# %% [markdown]
# ### Data processing

# %%
# !pip install nltk gensim
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
from gensim.models import Word2Vec
import ast

# %%
# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Define a function to preprocess the text data
def preprocess_text(text):
    # Tokenize the text
    tokens = word_tokenize(text.lower())  # convert to lowercase and tokenize

    # Remove stopwords and punctuation
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words and word not in string.punctuation]

    return tokens

# %%
data = pd.read_csv("/content/TCPD_QH.tsv", sep='\t', header=0, engine='python')

# %%
data.head()
# Out:
#          id                 date  ls_number  \
# 0  10173416  2017-08-02T00:00:00         16
# 1  10173216  2017-08-02T00:00:00         16
# 2  10173116  2017-08-02T00:00:00         16
# 3  10173016  2017-08-02T00:00:00         16
# 4  10172916  2017-08-02T00:00:00         16
#
#                                  ministry question_type  \
# 0                                Railways     Unstarred
# 1            Information and Broadcasting     Unstarred
# 2  Skill Development and Entrepreneurship     Unstarred
# 3               Housing and Urban Affairs     Unstarred
# 4                        Minority Affairs     Unstarred
#
#                                        question_text  \
# 0  (a) the number of cases which came to notice w...
# 1  (a) the salient features of the Community Radi...
# 2  (a) whether the India International Skill Cent...
# 3  Will the Minister of HOUSING AND URBAN AFFAIRS...
# 4  (a) whether the Government proposes to carry o...
#
#                                          answer_text  \
# 0  MINISTER OF STATE IN THE MINISTRY OF RAILWAYS ...
# 1  THE MINISTER OF STATE OF THE MINISTRY OF INFOR...
# 2  (a) to (e) As on date 14 India International S...
# 3  THE MINISTER OF STATE IN THE MINISTRY OF HOUSI...
# 4  MINISTER OF STATE (INDEPENDENT CHARGE) FOR MIN...
#
#                                     member     party             state  \
# 0                             RAJESH VERMA       BJP     Uttar Pradesh
# 1                            B. SREERAMULU       BJP         Karnataka
# 2  MEENAKASHI LEKHI, RAVINDRA KUMAR PANDEY  BJP, BJP  Delhi, Jharkhand
# 3                              RAJENDRAN S      ADMK        Tamil Nadu
# 4                              DILIP PATEL       BJP           Gujarat
#
#          constituency constituency_type        gender  \
# 0             Sitapur               GEN          Male
# 1             Bellary                ST          Male
# 2  New delhi, Giridih          GEN, GEN  Female, Male
# 3          Viluppuram                SC          Male
# 4               Anand               GEN          Male
#
#                                 subject  \
# 0  Cases of Fighting/Quarrels in Trains
# 1               Community Radio Station
# 2      India International Skill Centre
# 3            MoU with Reckitt Benckiser
# 4                    Employment Surveys
#
#                                                 link
# 0  https://loksabha.nic.in/Questions/QResult15.as...
# 1  https://loksabha.nic.in/Questions/QResult15.as...
# 2  https://loksabha.nic.in/Questions/QResult15.as...
# 3  https://loksabha.nic.in/Questions/QResult15.as...
# 4  https://loksabha.nic.in/Questions/QResult15.as...

# %%
data.dtypes
# Out:
# id                    int64
# date                 object
# ls_number             int64
# ministry             object
# question_type        object
# question_text        object
# answer_text          object
# member               object
# party                object
# state                object
# constituency         object
# constituency_type    object
# gender               object
# subject              object
# link                 object
# dtype: object

# %%
data.describe(include="all")
# Out:
#                   id                 date      ls_number ministry  \
# count   2.982930e+05               298293  298293.000000   298293
# unique           NaN                 1307            NaN       85
# top              NaN  2006-08-22T00:00:00            NaN  Finance
# freq             NaN                  256            NaN    20502
# mean    5.607618e+07                  NaN      14.549292      NaN
# std     3.649965e+08                  NaN       1.127031      NaN
# min     2.100018e+06                  NaN      13.000000      NaN
# 25%     1.164072e+07                  NaN      14.000000      NaN
# 50%     1.350611e+07                  NaN      15.000000      NaN
# 75%     1.537062e+07                  NaN      16.000000      NaN
# max     3.581100e+09                  NaN      16.000000      NaN
#
#        question_type  question_text  \
# count         298293         298251
# unique             2         297731
# top        Unstarred  URL_Not_Found
# freq          272810             77
# mean             NaN            NaN
# std              NaN            NaN
# min              NaN            NaN
# 25%              NaN            NaN
# 50%              NaN            NaN
# 75%              NaN            NaN
# max              NaN            NaN
#
#                                               answer_text  \
# count                                              298173
# unique                                             295375
# top     MINISTER OF STATE IN THE MINISTRY OF RAILWAYS ...
# freq                                                   38
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                        member   party        state constituency  \
# count                  298293  298293       298293       298293
# unique                  57051   17345        19691        54879
# top     ATHAWALE RAMDAS BANDU     BJP  Maharashtra    Hyderabad
# freq                     1602   69485        26764         2334
# mean                      NaN     NaN          NaN          NaN
# std                       NaN     NaN          NaN          NaN
# min                       NaN     NaN          NaN          NaN
# 25%                       NaN     NaN          NaN          NaN
# 50%                       NaN     NaN          NaN          NaN
# 75%                       NaN     NaN          NaN          NaN
# max                       NaN     NaN          NaN          NaN
#
#        constituency_type  gender                subject  \
# count             298293  298293                 298291
# unique              2643    1015                 234344
# top                  GEN    Male  RURAL ELECTRIFICATION
# freq              163994  193359                     83
# mean                 NaN     NaN                    NaN
# std                  NaN     NaN                    NaN
# min                  NaN     NaN                    NaN
# 25%                  NaN     NaN                    NaN
# 50%                  NaN     NaN                    NaN
# 75%                  NaN     NaN                    NaN
# max                  NaN     NaN                    NaN
#
#                                                      link
# count                                              298293
# unique                                             298293
# top     https://loksabha.nic.in/Questions/QResult15.as...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
data = data.dropna()

# %%
dataset = data['question_text']   # storing the questions column
dataset.astype(str)
# Out:
# 0         (a) the number of cases which came to notice w...
# 1         (a) the salient features of the Community Radi...
# 2         (a) whether the India International Skill Cent...
# 3         Will the Minister of HOUSING AND URBAN AFFAIRS...
# 4         (a) whether the Government proposes to carry o...
#                                 ...
# 298288    (a) whether there is any data sharing policy w...
# 298289    (a) the present status of various ongoing rail...
# 298290    (a) whether the Government has tried to assess...
# 298291    (a) whether the Government has received recomm...
# 298292    (a) the details of number of cases pending in ...
# Name: question_text, Length: 298171, dtype: object

# %%
# not needed for Zero shot
processed_dataset = [preprocess_text(text) for text in data['question_text'].astype(str)]

# %% [markdown]
# ### Part 1: Using word2vec for vectorisation of questions corpus

# %%
# train the Word2Vec model using the CBOW architecture
model = Word2Vec(sentences=processed_dataset, vector_size=100, window=5, min_count=1, workers=4, sg=0)

# %%
# finding words similar to 'woman'
similar_words = model.wv.most_similar('woman', topn=1000)

similar_words
# Out:
# [('couples', 0.7610868811607361),
#  ('daughters', 0.7294248938560486),
#  ('married', 0.7101222276687622),
#  ('wife', 0.6932497620582581),
#  ('husbands', 0.6872377991676331),
#  ('spouse', 0.6798301339149475),
#  ('his/her', 0.6721576452255249),
#  ('mothers', 0.6683943271636963),
#  ('person', 0.6636925339698792),
#  ('adolescents', 0.6612431406974792),
#  ('he/she', 0.6576167941093445),
#  ('parents', 0.6543503403663635),
#  ('husband', 0.6520535349845886),
#  ('aspirants', 0.6492419838905334),
#  ('separated', 0.6472859978675842),
#  ('dies', 0.6471075415611267),
#  ('kids', 0.6459189057350159),
#  ('lawyers', 0.6434658765792847),
#  ('divorced', 0.63853919506073),
#  ('foetuses', 0.636870801448822),
#  ('father', 0.6368151307106018),
#  ('deserted', 0.6356186866760254),
#  ('lactating', 0.6353264451026917),
#  ('divorcee', 0.6351039409637451),
#  ('sons', 0.6308828592300415),
#  ('wives', 0.6296428442001343),
#  ('philanthropists', 0.6272149085998535),
#  ('expectant', 0.6235759854316711),
#  ('minors', 0.6216840147972107),
#  ('beating', 0.6183339357376099),
#  ('adults', 0.6173526644706726),
#  ('journalists', 0.6172907948493958),
#  ('men/women', 0.6167616844177246),
#  ('anglo-indians', 0.6158753037452698),
#  ('unmarried', 0.6128018498420715),
#  ('illiterate', 0.6125699877738953),
#  ('babies', 0.6116175055503845),
#  ('spouses', 0.6099482774734497),
#  ('youngsters', 0.6089928150177002),
#  ('never', 0.6088539958000183),
#  ('pretext', 0.6062489748001099),
#  ('pregnant', 0.6062038540840149),
#  ('abused', 0.6059223413467407),
#  ('mere', 0.6001133918762207),
#  ('sibling', 0.5996000170707703),
#  ('slavery', 0.5995388031005859),
#  ('pain', 0.5990962982177734),
#  ('vote', 0.5989575982093811),
#  ('incapacitated', 0.5975675582885742),
#  ('aiba', 0.5975000858306885),
#  ('transgenders', 0.5972650051116943),
#  ('undergo', 0.5964899659156799),
#  ('employer', 0.5950426459312439),
#  ('orphanage', 0.5945554971694946),
#  ('fellow', 0.5919504165649414),
#  ('males', 0.5910832285881042),
#  ('eunuchs', 0.5908975601196289),
#  ('nurse', 0.5905619859695435),
#  ('genital', 0.5899037718772888),
#  ('respectable', 0.5880303978919983),
#  ('asis/sis', 0.5864265561103821),
#  ('aborting', 0.5841698050498962),
#  ('ill-treatment', 0.5825605392456055),
#  ('surrogate', 0.5816972851753235),
#  ('male', 0.5814238786697388),
#  ('sc/', 0.5813909769058228),
#  ('anms', 0.5803821086883545),
#  ('newborns', 0.5797486305236816),
#  ('establishments/organizations', 0.5785348415374756),
#  ('employee', 0.5783366560935974),
#  ('victimised', 0.5767046213150024),
#  ('co-pilots', 0.5766655206680298),
#  ('attend', 0.5755653977394104),
#  ('advocates', 0.5743354558944702),
#  ('friends', 0.5743052959442139),
#  ('women/', 0.5741780996322632),
#  ('emp-', 0.5741602778434753),
#  ('settings', 0.5739381909370422),
#  ('die', 0.5735911726951599),
#  ('tortured', 0.5733047127723694),
#  ('pregnancy', 0.5726850628852844),
#  ('artistes', 0.5726536512374878),
#  ('marriage', 0.57234787940979),
#  ('writers', 0.5723311901092529),
#  ('men', 0.5722053647041321),
#  ('reappointing', 0.5703707337379456),
#  ('chance', 0.5698842406272888),
#  ('disc', 0.5698092579841614),
#  ('widow', 0.569022536277771),
#  ('sarpanches', 0.5689807534217834),
#  ('honorary', 0.5688987970352173),
#  ('advocate', 0.5688959360122681),
#  ('deserting', 0.5681845545768738),
#  ('ill-', 0.5675825476646423),
#  ('bovs', 0.5665943622589111),
#  ('performers', 0.5665469169616699),
#  ('myanmarese', 0.5662487149238586),
#  ('traveller', 0.5657694935798645),
#  ('prostitutes', 0.5650756359100342),
#  ('all-women', 0.5647624731063843),
#  ('tend', 0.5647315382957458),
#  ('martyrdom', 0.5645237565040588),
#  ('918', 0.5638512969017029),
#  ('derogatory', 0.5634020566940308),
#  ('calves', 0.5626439452171326),
#  ('dependants', 0.5626266598701477),
#  ('persons/peoples', 0.5614162087440491),
#  ('succumb', 0.5612574219703674),
#  ('convicts', 0.5609411001205444),
#  ('leave', 0.5608683228492737),
#  ('slave', 0.5607908964157104),
#  ('womens', 0.5604197978973389),
#  ('rooms/toilets', 0.5595782995223999),
#  ('intellectuals', 0.5595665574073792),
#  ('worker', 0.5584833025932312),
#  ('ncwa-ix', 0.5584815740585327),
#  ('enrolling', 0.5580798983573914),
#  ('murdered', 0.5575557947158813),
#  ('mutilation', 0.5566567778587341),
#  ('electing', 0.5562556385993958),
#  ('merely', 0.5562500953674316),
#  ('trafficked', 0.5560568571090698),
#  ('infants', 0.5555110573768616),
#  ('leave/maternity', 0.5553828477859497),
#  ('volunteer', 0.5553069114685059),
#  ('__indira', 0.5548389554023743),
#  ('forty', 0.5546209812164307),
#  ('scores', 0.5542846918106079),
#  ('gang-rape', 0.5539998412132263),
#  ('teenagers', 0.553239107131958),
#  ('bureaucrats', 0.553149938583374),
#  ('visitation', 0.5529142022132874),
#  ('dependant', 0.5528456568717957),
#  ('midwives', 0.5523862838745117),
#  ('recruits', 0.5523569583892822),
#  ('premature', 0.551611065864563),
#  ('technocrats', 0.5513918995857239),
#  ('inter-caste', 0.5510273575782776),
#  ('handicap', 0.5510256886482239),
#  ('magazines/blogs/social', 0.5507384538650513),
#  ('wards', 0.5506884455680847),
#  ('employee/soldier', 0.5501648187637329),
#  ('citizen', 0.5497105717658997),
#  ('birthday', 0.5496619343757629),
#  ('veterinarians/ngos', 0.5495648384094238),
#  ('rapes', 0.5493173003196716),
#  ('visually', 0.5492972731590271),
#  ('indigent', 0.548839807510376),
#  ('workplace', 0.5483351945877075),
#  ('46,000', 0.5476303100585938),
#  ('beaten', 0.5474080443382263),
#  ('sexual', 0.5470597743988037),
#  ('ill-treated', 0.5470060110092163),
#  ('christian', 0.5469954609870911),
#  ('counseling', 0.5466932058334351),
#  ('torture', 0.5463703870773315),
#  ('wrist', 0.5452377200126648),
#  ('female', 0.5449111461639404),
#  ('brides', 0.544892430305481),
#  ('jiciumallstn', 0.5446340441703796),
#  ('disability', 0.5445555448532104),
#  ('jihadis', 0.5444227457046509),
#  ('arrested/cases', 0.5442187786102295),
#  ('incarcerated', 0.5434474945068359),
#  ('sepia-toned', 0.5431606769561768),
#  ('judge/', 0.5429807901382446),
#  ('battalions/number', 0.5426649451255798),
#  ('transgender', 0.542572557926178),
#  ('falsely', 0.542557418346405),
#  ('children/persons', 0.5425116419792175),
#  ('births', 0.5424524545669556),
#  ('assaults', 0.5421472191810608),
#  ('sodomised', 0.5421227216720581),
#  ('teenage', 0.5420800447463989),
#  ('ctizens', 0.5418595671653748),
#  ('talaq', 0.5414817929267883),
#  ('69', 0.5410875082015991),
#  ('honour', 0.541050910949707),
#  ('anaemic', 0.540771484375),
#  ('survivors', 0.5403950810432434),
#  ('widowed', 0.5401525497436523),
#  ('young', 0.5400508046150208),
#  ('anyone', 0.539665162563324),
#  ('uan', 0.5394174456596375),
#  ('retire', 0.5390376448631287),
#  ('12033', 0.538325309753418),
#  ('dignity', 0.5379783511161804),
#  ('destitute', 0.5377616882324219),
#  ('gestational', 0.5371267199516296),
#  ('son', 0.536566436290741),
#  ('scs/sts/weaker', 0.5364338755607605),
#  ('psychiatrists', 0.5358424782752991),
#  ('quit', 0.5357434153556824),
#  ('troupe', 0.5357087254524231),
#  ('identical', 0.5356112718582153),
#  ('mentally', 0.535567045211792),
#  ('bigamy', 0.5355111360549927),
#  ('birth', 0.5354365110397339),
#  ('flee', 0.535077691078186),
#  ('eveteasing', 0.5348652601242065),
#  ('widows/', 0.5347575545310974),
#  ('csbos', 0.5345177054405212),
#  ('free-teaching', 0.5343405604362488),
#  ('emotional', 0.5335476398468018),
#  ('insignificant', 0.5331882834434509),
#  ('exploitations', 0.5330061912536621),
#  ('jahan', 0.5328604578971863),
#  ('soldier', 0.5326716303825378),
#  ('chairpersons', 0.5320698022842407),
#  ('anm', 0.5320159196853638),
#  ('casteism', 0.5319178700447083),
#  ('half-widows', 0.5318148732185364),
#  ('women/children', 0.5316189527511597),
#  ('olympics-1900', 0.5314656496047974),
#  ('formon', 0.5314058065414429),
#  ('females', 0.5313887596130371),
#  ('read', 0.5310807228088379),
#  ('clubbed', 0.531021237373352),
#  ('amputated', 0.5309937000274658),
#  ('colleagues', 0.5309507250785828),
#  ('post-', 0.5307234525680542),
#  ('lashkar-e-taiba', 0.5304245948791504),
#  ('lured', 0.5303410291671753),
#  ('jain', 0.5302526950836182),
#  ('usually', 0.5300666093826294),
#  ('orphan', 0.5299422740936279),
#  ('attaining', 0.5299232602119446),
#  ('cfi', 0.529757559299469),
#  ('sikhs', 0.52972012758255),
#  ('orphans', 0.5294992327690125),
#  ('pluckers', 0.52945476770401),
#  ('stolen/kidnapped', 0.5293615460395813),
#  ('bds', 0.5292415618896484),
#  ('votes', 0.5292102694511414),
#  ('witness', 0.5290789604187012),
#  ('minds', 0.5290008783340454),
#  ('folded', 0.528761625289917),
#  ('artist', 0.5286772847175598),
#  ('lectures', 0.52802973985672),
#  ('minutes', 0.5276889204978943),
#  ('anymore', 0.5276871919631958),
#  ('kidnappers/touts', 0.526906430721283),
#  ('divorce', 0.5266532897949219),
#  ('dalit', 0.5261999368667603),
#  ('absconded', 0.5256453156471252),
#  ('women', 0.5256006121635437),
#  ('prayer', 0.5255899429321289),
#  ('pensioner', 0.5255352258682251),
#  ('professor', 0.5251087546348572),
#  ('sexually', 0.525083065032959),
#  ('supervisors', 0.5249968767166138),
#  ('12489/12490', 0.5248347520828247),
#  ('medically', 0.5242084264755249),
#  ('1.7.08', 0.5240470170974731),
#  ('personal', 0.5239202380180359),
#  ('invalid', 0.5237701535224915),
#  ('ewrs', 0.5237455368041992),
#  ('impaired', 0.5230762362480164),
#  ('honoring', 0.5230088233947754),
#  ('counsellors', 0.5228567719459534),
#  ('expose', 0.5228509902954102),
#  ('judge', 0.5227437019348145),
#  ('hopefuls', 0.5225788354873657),
#  ('abortion', 0.5221552848815918),
#  ('locomotors', 0.5219113826751709),
#  ('childen', 0.5216199159622192),
#  ('dismissal', 0.5213040113449097),
#  ('activist', 0.5212991237640381),
#  ('mr', 0.5211735963821411),
#  ('student', 0.5208297967910767),
#  ('muslim', 0.520795464515686),
#  ('bog', 0.5207306742668152),
#  ('policemen', 0.5204893946647644),
#  ('gaurav', 0.5201965570449829),
#  ('kalikesh', 0.5200359225273132),
#  ('tickets/berths', 0.5199715495109558),
#  ('reporters', 0.5199552774429321),
#  ('397', 0.5198977589607239),
#  ('successors', 0.5197221040725708),
#  ('became', 0.5195826292037964),
#  ('cat-hi', 0.5195175409317017),
#  ('alive', 0.5191207528114319),
#  ('maharshi', 0.5190761089324951),
#  ('elite', 0.519059419631958),
#  ('assamese', 0.5188137888908386),
#  ('87', 0.5186275839805603),
#  ('proxy', 0.5186249613761902),
#  ('psychologists', 0.5185583829879761),
#  ('obese', 0.5184949040412903),
#  ('portals', 0.5182796716690063),
#  ('genitoplasty', 0.5175298452377319),
#  ('appear', 0.5173159241676331),
#  ('cabin', 0.5172910690307617),
#  ('hildren', 0.5169941782951355),
#  ('relatives', 0.5167346000671387),
#  ('issueless', 0.5165910124778748),
#  ('inheritance', 0.5165702104568481),
#  ('articularly', 0.5164644122123718),
#  ('interview', 0.5164489150047302),
#  ('anniversaries', 0.516417384147644),
#  ('72years', 0.5161463022232056),
#  ('fathers', 0.5161423683166504),
#  ('dialogues/remarks/', 0.5160419940948486),
#  ('inmate', 0.5158494114875793),
#  ('pregnancies', 0.5156189799308777),
#  ('out-of-school', 0.5155893564224243),
#  ('anniversary', 0.5155845284461975),
#  ('instructor', 0.5154304504394531),
#  ('nomad', 0.5154130458831787),
#  ('educated', 0.5153515338897705),
#  ('riders', 0.5153447985649109),
#  ('cornea', 0.5151649713516235),
#  ('pillion', 0.514733076095581),
#  ('conception', 0.5146933794021606),
#  ('bright', 0.5146327614784241),
#  ('police/assistant', 0.5145098567008972),
#  ('motivated', 0.5143032670021057),
#  ('racial', 0.5142650008201599),
#  ('sentences', 0.513736367225647),
#  ('posthumously', 0.5136662125587463),
#  ('post-retirement', 0.5136241912841797),
#  ('attendants', 0.513283908367157),
#  ('registered/unregistered', 0.5131149888038635),
#  ('ladies', 0.5131055116653442),
#  ('dancers/performers', 0.5129239559173584),
#  ('homeless/old', 0.5127425193786621),
#  ('tongue', 0.5127280950546265),
#  ('claimsmade', 0.5126417875289917),
#  ('confirms', 0.5126028060913086),
#  ('kith', 0.5125427842140198),
#  ('recipients', 0.5125184655189514),
#  ('background', 0.5124747157096863),
#  ('include/', 0.5124131441116333),
#  ('happens', 0.5123521089553833),
#  ('marriageable', 0.512259840965271),
#  ('born', 0.5121982097625732),
#  ('row', 0.5121545195579529),
#  ('b.tech', 0.512103259563446),
#  ('represent', 0.5120107531547546),
#  ('readers', 0.5119418501853943),
#  ('fled', 0.5118077993392944),
#  ('servicemen/', 0.5112161636352539),
#  ('detained/faced', 0.5111332535743713),
#  ('hundreds', 0.5110904574394226),
#  ('full-time', 0.5109443068504333),
#  ('reinstating', 0.5106277465820312),
#  ('shocking', 0.5106036067008972),
#  ('atleast', 0.5105916857719421),
#  ('untrained', 0.5105509757995605),
#  ('practically', 0.5104491710662842),
#  ('125', 0.5102381110191345),
#  ('newborn', 0.5101768374443054),
#  ('kidnapped', 0.5101054310798645),
#  ('uneducated', 0.510053813457489),
#  ('islam', 0.5100011229515076),
#  ('19609/19610', 0.5099307894706726),
#  ('overnight', 0.5097442865371704),
#  ('js', 0.5097010135650635),
#  ('38', 0.5096848011016846),
#  ('crew', 0.5096692442893982),
#  ('perpetuation', 0.5096386671066284),
#  ('anxiety', 0.5094559788703918),
#  ('45,000', 0.5093631148338318),
#  ('_a__', 0.509255588054657),
#  ('witnesses', 0.5091401934623718),
#  ('depression', 0.5090144276618958),
#  ('doctor', 0.5090062022209167),
#  ('mellitus', 0.5089668035507202),
#  ('waiters', 0.5088516473770142),
#  ('saints', 0.5088182091712952),
#  ('bride/', 0.5086340308189392),
#  ('new-born', 0.5084585547447205),
#  ('abortion/termination', 0.5083408355712891),
#  ('60-65', 0.5082939267158508),
#  ('10+2', 0.5082607269287109),
#  ('mutilating', 0.508227527141571),
#  ('areas/farmers', 0.5081900954246521),
#  ('live-in-relationship', 0.5081468224525452),
#  ('rs.1.72', 0.5079925060272217),
#  ('aggrieved', 0.5079432725906372),
#  ('junior', 0.5078069567680359),
#  ('watching', 0.5076317191123962),
#  ('entitlements', 0.507607102394104),
#  ('photographers', 0.5075576305389404),
#  ('aged', 0.5075132250785828),
#  ('classroom', 0.50750333070755),
#  ('impersonation', 0.5074998736381531),
#  ('1000-1500', 0.507473349571228),
#  ('sub-quota', 0.5072852373123169),
#  ('whales', 0.5072433352470398),
#  ('difficulty/deprivation', 0.5071722269058228),
#  ('privilege', 0.5071296691894531),
#  ('teachings', 0.5070870518684387),
#  ('adulthood', 0.5070692896842957),
#  ('infanticide', 0.5068287253379822),
#  ('venkatesh', 0.5067619681358337),
#  ('fine-arts', 0.5066242218017578),
#  ('singers', 0.5061302781105042),
#  ('mazdoors', 0.5060950517654419),
#  ('blind', 0.5060701966285706),
#  ('recipient', 0.5059765577316284),
#  ('children/physically', 0.5058903098106384),
#  ('actor', 0.5058095455169678),
#  ('gymnasts', 0.5057772994041443),
#  ('thalassemia', 0.505657434463501),
#  ('farmer/cultivators/', 0.5055932402610779),
#  ('politics', 0.5054365992546082),
#  ('pio', 0.5053719282150269),
#  ('violent', 0.5052078366279602),
#  ('compensation/', 0.505145788192749),
#  ('12034', 0.504877507686615),
#  ('21.12.2015.', 0.5047610998153687),
#  ('offences/crime', 0.5046131014823914),
#  ('cross-shooting', 0.5045952796936035),
#  ('73', 0.5045478343963623),
#  ('staffs', 0.5045258402824402),
#  ('destitution', 0.5044226050376892),
#  ('csbo', 0.5043924450874329),
#  ('non-permanent', 0.5043746829032898),
#  ('parent', 0.5041744112968445),
#  ('sarpanch', 0.5040947198867798),
#  ('laptop', 0.5040246844291687),
#  ('trip', 0.5039793252944946),
#  ('impoverished', 0.5037175416946411),
#  ('rs.1500/-', 0.5036409497261047),
#  ('capfs', 0.5034730434417725),
#  ('iccidd', 0.503057062625885),
#  ('death', 0.5029982924461365),
#  ('physically', 0.5028548240661621),
#  ('fear', 0.5028043985366821),
#  ('lady', 0.5027251839637756),
#  ('elderly', 0.5025171637535095),
#  ('joyrides', 0.5023556351661682),
#  ('politicians', 0.5019643306732178),
#  ('literate', 0.5018606185913086),
#  ('impairment', 0.5018230676651001),
#  ('sterilisation', 0.5016382932662964),
#  ('info-system', 0.5015948414802551),
#  ('abandoning', 0.5015681982040405),
#  ('slip', 0.501541256904602),
#  ('scs/sts/obcs', 0.5015087127685547),
#  ('sehri', 0.5014970898628235),
#  ('46', 0.5014899373054504),
#  ('maharashtr', 0.5014649033546448),
#  ('mastermind', 0.501434326171875),
#  ('barret', 0.5014309883117676),
#  ('laddu', 0.5014177560806274),
#  ('coolies', 0.5013045072555542),
#  ('students/interns/veterinary', 0.5012665390968323),
#  ('53', 0.501132607460022),
#  ('z.r', 0.5009952783584595),
#  ('i-vii', 0.5009793043136597),
#  ('petty', 0.5008414387702942),
#  ('selective', 0.5007323622703552),
#  ('orphaned', 0.5007235407829285),
#  ('lowincome', 0.5005701780319214),
#  ('died/', 0.5003834962844849),
#  ('commit', 0.5003687143325806),
#  ('karmapa', 0.5003606081008911),
#  ('perpetrated', 0.5003518462181091),
#  ('commanders', 0.5003455281257629),
#  ('housewives', 0.5002607703208923),
#  ('1070.', 0.5001761317253113),
#  ('women/men', 0.5000786781311035),
#  ('14.4', 0.5000630021095276),
#  ('routinely', 0.5000608563423157),
#  ('widows', 0.5000579953193665),
#  ('adi', 0.49999329447746277),
#  ('6600/-', 0.4999876320362091),
#  ('lucrative', 0.4998307526111603),
#  ('ages', 0.4996885359287262),
#  ('restlessness', 0.4996850788593292),
#  ('desirous', 0.4996448755264282),
#  ('children', 0.49956202507019043),
#  ('lndia', 0.49955183267593384),
#  ('abuses', 0.4994840919971466),
#  ('pm', 0.499434232711792),
#  ('d.rayatwari', 0.49939975142478943),
#  ('dentists', 0.4993599057197571),
#  ('daughter', 0.4993562400341034),
#  ('assault', 0.4993318021297455),
#  ('words', 0.4991041123867035),
#  ('gang-men', 0.4989151656627655),
#  ('vc', 0.49888190627098083),
#  ('quota-wise', 0.4988621175289154),
#  ('spouse/family', 0.49881070852279663),
#  ('hardwork', 0.4986306428909302),
#  ('12448/12447', 0.49861064553260803),
#  ('confined', 0.49858906865119934),
#  ('argument', 0.49856188893318176),
#  ('servicemen', 0.49855712056159973),
#  ('exem-', 0.498354971408844),
#  ('live', 0.49821722507476807),
#  ('molestation', 0.49815189838409424),
#  ('epic', 0.4981515407562256),
#  ('assents', 0.49801576137542725),
#  ('seafarers', 0.49797824025154114),
#  ('offending', 0.4979306161403656),
#  ('courage', 0.497734397649765),
#  ('cricketers', 0.4977248013019562),
#  ('ering', 0.4976014494895935),
#  ('sometimes', 0.49751561880111694),
#  ('historian', 0.49734747409820557),
#  ('1,700', 0.49733009934425354),
#  ('39', 0.4972580671310425),
#  ('drafton', 0.4972253143787384),
#  ('pakistanis', 0.49721404910087585),
#  ('philosophy', 0.49720221757888794),
#  ('no.1002', 0.4971792995929718),
#  ('3,09,000', 0.4971775710582733),
#  ('copy', 0.49708783626556396),
#  ('reintegration', 0.49701687693595886),
#  ('ante-natal', 0.49694493412971497),
#  ('deaf', 0.49692896008491516),
#  ('christians', 0.4968618154525757),
#  ('scribes', 0.4965709447860718),
#  ('eol', 0.49647149443626404),
#  ('judges/', 0.4963906705379486),
#  ('citizens/old', 0.49635520577430725),
#  ('oncologists', 0.49613943696022034),
#  ('serving/', 0.49597278237342834),
#  ('anxious', 0.4959591031074524),
#  ('to/intended', 0.4957903325557709),
#  ('salary/', 0.4956599175930023),
#  ('aisle', 0.4955473840236664),
#  ('non-metros', 0.49553877115249634),
#  ('received/suo', 0.4954094886779785),
#  ('inherit', 0.495373398065567),
#  ('maternity', 0.49536699056625366),
#  ('cards/disbursal', 0.49531373381614685),
#  ('staged', 0.4953121542930603),
#  ('destitutes', 0.4953097403049469),
#  ('18.49', 0.4952748417854309),
#  ('requiredinformation', 0.4952085018157959),
#  ('staying/', 0.4948507249355316),
#  ('hysterectomy', 0.49454256892204285),
#  ('position/member', 0.49447086453437805),
#  ('orthopaedically', 0.4944620132446289),
#  ('photographs', 0.4944526255130768),
#  ('chairperson', 0.4942568242549896),
#  ('rightsseeking', 0.49424460530281067),
#  ('dignified', 0.49419790506362915),
#  ('handedly', 0.4941447973251343),
#  ('active-learning', 0.4940323829650879),
#  ('saoner-i', 0.49392107129096985),
#  ('sec', 0.49388259649276733),
#  ('indecent', 0.49371933937072754),
#  ('chittu', 0.49356701970100403),
#  ('nri/pio/ocis', 0.493487149477005),
#  ('patriot', 0.4933328628540039),
#  ('eyes/eye', 0.49330660700798035),
#  ('p.m.', 0.49324461817741394),
#  ('antecedents', 0.49323004484176636),
#  ('peons', 0.4930621385574341),
#  ('2148.', 0.4930025637149811),
#  ('muster', 0.49285757541656494),
#  ('tubectomy', 0.4927557706832886),
#  ('subjecting', 0.4926852881908417),
#  ('seekers', 0.4926466643810272),
#  ('complainant', 0.4925887882709503),
#  ('officially', 0.4924998879432678),
#  ('employed/self-employed', 0.49236077070236206),
#  ('apprentices', 0.4923076927661896),
#  ('conveyance', 0.4922547936439514),
#  ('dumb', 0.49223142862319946),
#  ('artists', 0.49219006299972534),
#  ('children/women', 0.4921833872795105),
#  ('boys', 0.49211186170578003),
#  ('bachelors', 0.4920744001865387),
#  ('adolescent-sabha', 0.49204370379447937),
#  ('untraced', 0.4919993579387665),
#  ('jury', 0.4919432997703552),
#  ('professional/vocational', 0.491768479347229),
#  ('calls/smss', 0.49171048402786255),
#  ('deserving', 0.4916972815990448),
#  ('inconvenienced', 0.49167492985725403),
#  ('83', 0.49167197942733765),
#  ('jokes', 0.4916243553161621),
#  ('announcers', 0.49162209033966064),
#  ('unborn', 0.4913686215877533),
#  ('skinned', 0.4911905527114868),
#  ('deformity', 0.49111220240592957),
#  ('girl', 0.4910978376865387),
#  ('necessarily', 0.4910880923271179),
#  ('bgcs', 0.4910162389278412),
#  ('comfort', 0.4909907281398773),
#  ('fewer', 0.4909866452217102),
#  ('1970s', 0.4908614456653595),
#  ('prisoner', 0.4908047616481781),
#  ('ons', 0.4906828999519348),
#  ('distinction', 0.4904429614543915),
#  ('ias/ips/irs', 0.49019941687583923),
#  ('comedy', 0.4900127649307251),
#  ('tgt/', 0.4900094270706177),
#  ('departments/institutes', 0.4899701178073883),
#  ('heir', 0.48979654908180237),
#  ('revolutionaries', 0.4897184371948242),
#  ('sixty', 0.4897141754627228),
#  ('sweepers', 0.48967093229293823),
#  ('h-10', 0.48961523175239563),
#  ('batch', 0.48956286907196045),
#  ('ca', 0.4895554482936859),
#  ('pillar', 0.48949095606803894),
#  ('laskar-e-taiba', 0.48938411474227905),
#  ('2026', 0.4893534183502197),
#  ('profanities', 0.48907411098480225),
#  ('superannuated', 0.48892849683761597),
#  ('self-employed', 0.4888836741447449),
#  ('12.70', 0.4888351857662201),
#  ('convict', 0.48881104588508606),
#  ('molested', 0.48879438638687134),
#  ('institutions/churches', 0.4887266457080841),
#  ('awbi', 0.4886206388473511),
#  ('hoards', 0.4885885715484619),
#  ('64', 0.48855674266815186),
#  ('parliamentarians', 0.4884350001811981),
#  ('transferable', 0.488415390253067),
#  ('ph.d', 0.4883826971054077),
#  ('migrant', 0.4880851209163666),
#  ('12569/12570', 0.4880785048007965),
#  ('felicitation', 0.48800787329673767),
#  ('helpless', 0.4880032539367676),
#  ('rrb', 0.48797860741615295),
#  ('neonatal', 0.4879339337348938),
#  ('drms', 0.48792794346809387),
#  ('backwards/forwards/', 0.48788687586784363),
#  ('elders', 0.48784685134887695),
#  ('divyangs/differently', 0.4878056049346924),
#  ('entitles', 0.4877844452857971),
#  ('cry', 0.48765939474105835),
#  ('_post', 0.48753172159194946),
#  ('underfur', 0.48748964071273804),
#  ('volunteers', 0.48748457431793213),
#  ('neutral', 0.4874289333820343),
#  ('unemployable', 0.48719486594200134),
#  ('sepsis', 0.4871571362018585),
#  ('90000', 0.4871293604373932),
#  ('adolescent', 0.48712021112442017),
#  ('overstaying', 0.4870883524417877),
#  ('officers/personnel', 0.48707452416419983),
#  ('co-pilot', 0.4870311915874481),
#  ('diabetics', 0.4869558811187744),
#  ('speaker', 0.48693719506263733),
#  ('murders', 0.4868146479129791),
#  ('sikh', 0.4867112636566162),
#  ('inter-country', 0.4865604639053345),
#  ('feeling', 0.4864884614944458),
#  ('foreigners', 0.48648759722709656),
#  ('gm/executive', 0.4864788353443146),
#  ('presidents', 0.4864594638347626),
#  ('lama', 0.4863676428794861),
#  ('paradise', 0.48634836077690125),
#  ('classes/minorities/women', 0.48629897832870483),
#  ('infertility', 0.4861573278903961),
#  ('16-18', 0.48615390062332153),
#  ('acceptedby', 0.4858485758304596),
#  ('hapless', 0.48583224415779114),
#  ('27.7.2015', 0.4857914447784424),
#  ('soaks', 0.4857614040374756),
#  ('stipend', 0.4856027066707611),
#  ('gulzarbagh', 0.4855288565158844),
#  ('torturing', 0.4854808449745178),
#  ('fauj', 0.4854589104652405),
#  ('seafarers/sailors', 0.48543426394462585),
#  ('mujahideen', 0.48536840081214905),
#  ('passwords', 0.48529762029647827),
#  ('affected/', 0.48529595136642456),
#  ('lities', 0.48521506786346436),
#  ('humiliation', 0.48521092534065247),
#  ('rapist', 0.48516547679901123),
#  ('cochlear', 0.4851405620574951),
#  ('101215310.25', 0.4850354790687561),
#  ('litigants', 0.48499128222465515),
#  ('goons', 0.4849826991558075),
#  ('footage', 0.4848988354206085),
#  ('examiners', 0.48487475514411926),
#  ('injections/antidotes', 0.48474234342575073),
#  ('diplomats', 0.48463353514671326),
#  ('compensation/medical', 0.48461660742759705),
#  ('group-i', 0.48459258675575256),
#  ('2600th', 0.48445191979408264),
#  ('somalian', 0.4842691719532013),
#  ('destitute/minors/underage', 0.48417818546295166),
#  ('mausoleum', 0.4841563105583191),
#  ('report,2011', 0.4841543436050415),
#  ('taungyas', 0.4840347170829773),
#  ('14.1', 0.48396188020706177),
#  ('pmsss', 0.48382994532585144),
#  ('ambulifts', 0.48382440209388733),
#  ('abandonment', 0.4837782680988312),
#  ('interpol', 0.48363614082336426),
#  ('resident', 0.48358672857284546),
#  ('violence/atrocities', 0.48357871174812317),
#  ('sensationalization', 0.4835536479949951),
#  ('people/rural', 0.48331403732299805),
#  ('act-', 0.48329487442970276),
#  ('prostitution', 0.4832334518432617),
#  ('67', 0.483227401971817),
#  ('decisions/judg-', 0.4831438660621643),
#  ('irnss-1a', 0.4830808937549591),
#  ('virudhunagar', 0.483071893453598),
#  ('baramad', 0.4830326735973358),
#  ('hindus', 0.4829637408256531),
#  ('domicile', 0.4829045236110687),
#  ('puranic', 0.4826562702655792),
#  ('hailing', 0.4826357364654541),
#  ('sabha/vidhan', 0.48253414034843445),
#  ('larship', 0.4824931025505066),
#  ('anemia', 0.48239439725875854),
#  ('pink', 0.48233476281166077),
#  ('ganesha', 0.4822748601436615),
#  ('piace', 0.48227399587631226),
#  ('journalist', 0.48225340247154236),
#  ('unverifiable', 0.48220860958099365),
#  ('hate', 0.4821866750717163),
#  ('retired', 0.48200908303260803),
#  ('dont', 0.4819505512714386),
#  ('eat', 0.4818294644355774),
#  ('legally', 0.48181188106536865),
#  ('__3rd', 0.48155900835990906),
#  ('reader', 0.48135384917259216),
#  ('umbilical', 0.4811994731426239),
#  ('disrepute', 0.481159508228302),
#  ('retired/', 0.481151819229126),
#  ('menstruation', 0.48113250732421875),
#  ('perils', 0.4811181426048279),
#  ('8/-', 0.4810951352119446),
#  ('caste-based', 0.4810594916343689),
#  ('oldest', 0.48096156120300293),
#  ('magazine', 0.480845183134079),
#  ('release/publish', 0.48084113001823425),
#  ('guaranteed', 0.4808374047279358),
#  ('bhasha', 0.48067525029182434),
#  ('employ', 0.48066577315330505),
#  ('138', 0.48064950108528137),
#  ('cation', 0.48062863945961),
#  ('conjugal', 0.48061278462409973),
#  ('argue', 0.48058387637138367),
#  ('irrespective', 0.48034757375717163),
#  ('registry', 0.48024946451187134),
#  ('antecedants', 0.4801354706287384),
#  ('w.r.t', 0.47996747493743896),
#  ('harshly', 0.4799107611179352),
#  ('employable', 0.479884535074234),
#  ('empowerment/welfare/development', 0.4797652065753937),
#  ('radicalised', 0.47975876927375793),
#  ('imran', 0.4797265827655792),
#  ('parades', 0.4795893728733063),
#  ('gaza', 0.4795389473438263),
#  ('crimes/', 0.47949856519699097),
#  ('ex-pms', 0.4794642925262451),
#  ('beingconducted', 0.4792955815792084),
#  ('attack/', 0.4792638421058655),
#  ('sdis', 0.4792610704898834),
#  ('poorabiya', 0.47925886511802673),
#  ('30.11.2015', 0.47924044728279114),
#  ('220', 0.47917690873146057),
#  ('retarded', 0.4791654348373413),
#  ('motu', 0.47915688157081604),
#  ('chair', 0.4791133999824524),
#  ('439', 0.479109525680542),
#  ('ninety', 0.47907423973083496),
#  ('jatre', 0.47900497913360596),
#  ('rs.1.0', 0.4789956212043762),
#  ('similarly', 0.47889068722724915),
#  ('foodarticles', 0.47875431180000305),
#  ('depict', 0.47870171070098877),
#  ('1.35', 0.4786078631877899),
#  ('whistleblowers', 0.47850266098976135),
#  ('/trading', 0.4783017635345459),
#  ('sympathisers', 0.47814637422561646),
#  ('bureaucrats/', 0.4781307280063629),
#  ('eve-teasing', 0.47803795337677),
#  ('bar', 0.477990984916687),
#  ('institutions/central', 0.47780999541282654),
#  ('forcewise', 0.47774335741996765),
#  ('ministry__s', 0.4776727855205536),
#  ('rumours', 0.4775775671005249),
#  ('artisan', 0.47755447030067444),
#  ('jana', 0.47754839062690735),
#  ('refrain', 0.4775455594062805),
#  ('correspondents', 0.47753632068634033),
#  ('yment', 0.4774790108203888),
#  ('aspiring', 0.4773271679878235),
#  ('a.p.j', 0.47729429602622986),
#  ('loyment', 0.4772481918334961),
#  ('victim', 0.4772094488143921),
#  ('porters', 0.47720810770988464),
#  ('thesis', 0.47715792059898376),
#  ('pradyuman', 0.47711512446403503),
#  ('posters', 0.4769246280193329),
#  ('anusandhana', 0.4768672287464142),
#  ('debates', 0.4768229126930237),
#  ('walk', 0.47675788402557373),
#  ('hi', 0.4767575263977051),
#  ('stunted/under', 0.47673434019088745),
#  ('delinquency', 0.47671324014663696),
#  ('taxi/auto', 0.4766916334629059),
#  ('wean', 0.4765424430370331),
#  ('distinct', 0.4765068590641022),
#  ('undertrial', 0.4764869213104248),
#  ('crossed', 0.47648632526397705),
#  ('unto', 0.47648632526397705),
#  ('triple', 0.476370245218277),
#  ('nati-', 0.47634732723236084),
#  ('ongc/ovl/oil', 0.47631505131721497),
#  ('excel', 0.4762742221355438),
#  ('2-2.5', 0.4762515723705292),
#  ('braile', 0.4762146472930908),
#  ('ighters', 0.4760981798171997),
#  ('farming/cluster', 0.47591862082481384),
#  ('meted', 0.4757901132106781),
#  ('1.55', 0.4757325351238251),
#  ('sitting', 0.475715696811676),
#  ('choose', 0.47569793462753296),
#  ('remittances/private', 0.4756549596786499),
#  ('morcha', 0.4756019115447998),
#  ('electors', 0.47534236311912537),
#  ('postman', 0.47528061270713806),
#  ('vice-presidents', 0.4751935601234436),
#  ('egmont', 0.47513213753700256),
#  ('monochrome', 0.47512468695640564),
#  ('brilliant', 0.4750143885612488),
#  ('sambalpuri', 0.4749298691749573),
#  ('aboard', 0.4748212695121765),
#  ('survive', 0.4747949540615082),
#  ('complaints/incidents', 0.47473999857902527),
#  ('bullies', 0.47461047768592834),
#  ('liberty', 0.47450563311576843),
#  ('abstain', 0.4744971692562103),
#  ('re-marriaged', 0.47449639439582825),
#  ('tibetan', 0.4744260907173157),
#  ('asylum', 0.47442182898521423),
#  ('practising', 0.4743906259536743),
#  ('3126448', 0.4743710160255432),
#  ('stickers', 0.47434327006340027),
#  ('kidnapping', 0.4743386209011078),
#  ('witchcraft', 0.47428539395332336),
#  ('bleach', 0.474210262298584),
#  ('/ex-', 0.47412335872650146),
#  ('honours', 0.4740806221961975),
#  ('rs.6000/-', 0.47406938672065735),
#  ('ntagi', 0.4740614593029022),
#  ('fated', 0.4740141034126282),
#  ('post-graduates', 0.47398796677589417),
#  ('workmen', 0.4737834334373474),
#  ('fifa', 0.47378334403038025),
#  ('coverageas', 0.473724365234375),
#  ('literatures', 0.4737192988395691),
#  ('parti-', 0.47368744015693665),
#  ('wish', 0.4735530614852905),
#  ('white-backed', 0.47354528307914734),
#  ('trapped', 0.47348552942276),
#  ('detain', 0.4734731912612915),
#  ('crimes/atrocities', 0.47346171736717224),
#  ('hrs', 0.47342586517333984),
#  ('rape/', 0.47337526082992554),
#  ('course/', 0.473359078168869),
#  ('separate/distinct', 0.47317638993263245),
#  ('150th', 0.4731605648994446),
#  ('foreigner', 0.47309955954551697),
#  ('cerebral', 0.47300592064857483),
#  ('bargain', 0.47297775745391846),
#  ('goddesses', 0.4729699492454529),
#  ('ashas', 0.4729653298854828),
#  ('safety/', 0.4727768898010254),
#  ('unavoi-', 0.47264784574508667),
#  ('wards/children', 0.4726087749004364),
#  ('interventional', 0.47258394956588745),
#  ('endow', 0.4725656807422638),
#  ('1april', 0.4725289046764374),
#  ('md', 0.47229474782943726),
#  ('word', 0.4722713530063629),
#  ('maltreatment', 0.4722650349140167),
#  ('thirds', 0.4721212387084961),
#  ('muslims', 0.4721086025238037),
#  ('rohilla-rewari-loharu-', 0.4721073508262634),
#  ('savvy', 0.47193506360054016),
#  ('exam-wise', 0.47173160314559937),
#  ('scientist', 0.47169065475463867),
#  ('cervical', 0.47163599729537964),
#  ('demoralise', 0.47148939967155457),
#  ('life-styles', 0.47148701548576355),
#  ('karmacharis', 0.47147688269615173),
#  ('speeches', 0.4714347720146179),
#  ('mps__', 0.47134098410606384),
#  ('prevented', 0.47132593393325806),
#  ('de-sub-categorisation', 0.47129642963409424),
#  ('offence', 0.47125235199928284),
#  ('ssb', 0.47120827436447144),
#  ('495.00', 0.47118163108825684),
#  ('anwhar', 0.471163272857666),
#  ('abduct', 0.4711480438709259),
#  ('3525.', 0.47114747762680054),
#  ('emigrants', 0.47113558650016785),
#  ('completed/incompleted', 0.4711263179779053),
#  ('grooming', 0.4711233079433441),
#  ('obesity', 0.4710323214530945),
#  ('trained/employed', 0.4709673821926117),
#  ('unfortunate', 0.4709329307079315),
#  ('job-', 0.470816969871521),
#  ('andpermanent', 0.4706532061100006),
#  ('non-st', 0.4705623686313629),
#  ('male/female', 0.47054022550582886),
#  ('cariappa', 0.4705265164375305),
#  ('criticality', 0.47047123312950134),
#  ('lous', 0.4704693555831909),
#  ('privileges', 0.4703943431377411),
#  ('scho-', 0.4703449010848999),
#  ('antenatal', 0.47031688690185547),
#  ('marriages', 0.4703027606010437),
#  ('demise', 0.4701002538204193),
#  ('acrs', 0.4700813889503479),
#  ('commemorate', 0.4699212908744812),
#  ('mavoor', 0.46984532475471497),
#  ('seatbelts', 0.46979430317878723),
#  ('171.', 0.46978694200515747),
#  ('18-35', 0.4697791635990143),
#  ('poorer', 0.4697638154029846),
#  ('cops', 0.4697232246398926),
#  ('misbehaviour', 0.4695749282836914),
#  ('tokens', 0.46955400705337524),
#  ('15-29', 0.4694303274154663),
#  ('interests/', 0.46935325860977173),
#  ('knowing', 0.4693142771720886),
#  ('suicidal', 0.46923181414604187),
#  ('mainstreaming', 0.46921810507774353),
#  ('68100', 0.46918967366218567),
#  ('fugitive', 0.46908289194107056),
#  ('ear', 0.46905484795570374),
#  ('least', 0.4690292477607727),
#  ('unclean', 0.4689554274082184),
#  ('hostages', 0.4689100682735443),
#  ('contest', 0.46888020634651184),
#  ('accompanying', 0.46887099742889404),
#  ('seconds', 0.4688538908958435),
#  ('password', 0.46881330013275146),
#  ('48.1', 0.46880263090133667),
#  ('newspapers/magazines', 0.46876636147499084),
#  ('3.6', 0.46870186924934387),
#  ('challenged', 0.46858084201812744),
#  ('belch', 0.4685782492160797),
#  ('curiosity', 0.46855148673057556),
#  ('religion', 0.4685402512550354),
#  ('orphanages', 0.46849942207336426),
#  ('twenty', 0.46847373247146606),
#  ('journalism', 0.4684532582759857),
#  ('anglo-indian', 0.46843016147613525),
#  ('tibetans', 0.4683484137058258),
#  ('inspire', 0.46830710768699646),
#  ('conser-', 0.4682445526123047),
#  ('palsy', 0.4682020843029022),
#  ('bride', 0.46818432211875916),
#  ('201565', 0.4681757390499115),
#  ('graduates', 0.4681739807128906),
#  ('stars', 0.4680292308330536),
#  ('imam', 0.4680177867412567),
#  ('paternity', 0.4679699242115021),
#  ('vitthal', 0.46796688437461853),
#  ('ideologies', 0.4679638147354126),
#  ('132610', 0.4678887724876404),
#  ('scientists/employees', 0.4678781032562256),
#  ('phil', 0.46787458658218384),
#  ('exploitation/', 0.46775972843170166),
#  ('multilingual', 0.46764621138572693),
#  ('21.6.2013', 0.4676154553890228),
#  ('anci-', 0.4676124155521393),
#  ('minorities/perceived', 0.4676113724708557),
#  ('61020', 0.46754443645477295),
#  ('ug', 0.46749749779701233),
#  ('fifty', 0.46749261021614075),
#  ('dowry', 0.4674771726131439),
#  ('struggle', 0.4674695134162903),
#  ('pandits', 0.4674491882324219),
#  ('nrai', 0.4674129784107208),
#  ('detained', 0.4673002064228058),
#  ('usual', 0.4671767055988312),
#  ('21.94', 0.4671022891998291),
#  ('biographies', 0.4670686423778534),
#  ('ex-servicemen', 0.466991662979126),
#  ('ption', 0.4669908285140991),
#  ('exservicemen', 0.4669901430606842),
#  ('nehariya', 0.46694695949554443),
#  ('non-admission', 0.46689653396606445),
#  ('exam', 0.4668594300746918),
#  ('habitual', 0.4667632579803467),
#  ('marital', 0.4667622745037079),
#  ('insane', 0.46672582626342773),
#  ('camera', 0.4666580259799957),
#  ('fourteen', 0.46662360429763794),
#  ('editors', 0.4666035771369934),
#  ('m.phil', 0.4666001796722412),
#  ('complications', 0.4665754735469818),
#  ('persons/faculty', 0.46650028228759766),
#  ('thrice', 0.46639159321784973),
#  ('cfr', 0.46636804938316345),
#  ('gdm', 0.4661879539489746),
#  ('nationalism/', 0.4660877585411072),
#  ('campbellbay', 0.46608665585517883),
#  ('bravery', 0.4660673439502716)]

# %%
new_data = pd.DataFrame(similar_words, columns=['Word', 'Score'])

# %%
new_data.to_csv("words_data.csv")

# %%
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(similar_words)

# %%
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Part 2: PSM and outcome analysis

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors

# %%
df = data.copy()

# %%
df['question_text'] = df['question_text'].apply(preprocess_text)  # Use the preprocess_text function from earlier
df['answer_text'] = df['answer_text'].apply(preprocess_text)

# %%
df['woman_count'] = df['question_text'].apply(lambda x: x.count('woman')) # counting occurences per question

# %%
df.head()

# %%
# Define your independent variables (X) and dependent variable (y)
X = df[['ministry', 'party', 'state', 'constituency', 'constituency_type']]
y = df['gender'] == 'Female'  # Assuming you're using gender to define propensity

# Convert categorical variables to dummy variables
X = pd.get_dummies(X)

# Calculate propensity scores
log_reg = LogisticRegression()
log_reg.fit(X, y)
df['propensity_score'] = log_reg.predict_proba(X)[:, 1]

# %% [markdown]
# ### Zero Shot Classification

# %%
pip install transformers==3.1.0
# Out:
# Collecting transformers==3.1.0
#   Downloading transformers-3.1.0-py3-none-any.whl (884 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 884.0/884.0 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from transformers==3.1.0) (1.25.2)
# Collecting tokenizers==0.8.1.rc2 (from transformers==3.1.0)
#   Downloading tokenizers-0.8.1rc2.tar.gz (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.4/97.4 kB 8.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from transformers==3.1.0) (24.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==3.1.0) (3.13.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==3.1.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==3.1.0) (4.66.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==3.1.0) (2023.12.25)
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.10/dist-packages (from transformers==3.1.0) (0.1.99)
# Collecting sacremoses (from transformers==3.1.0)
#   Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==3.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==3.1.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==3.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==3.1.0) (2024.2.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers==3.1.0) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers==3.1.0) (1.3.2)
# Building wheels for collected packages: tokenizers
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for tokenizers (pyproject.toml) ... error
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# ERROR: Could not build wheels for tokenizers, which is required to install pyproject.toml-based projects

# %%
from transformers import pipeline

# %%
classifier = pipeline("zero-shot-classification", batch_size=8, device=0) # to utilize GPU
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
labels = ['corruption', 'development', 'accountability and transparency', 'programmatic representation', 'clientelistic representation']

# %%
# cleaning data
data = data.dropna()
data = data.astype(str)

# %%
from nltk.stem.wordnet import WordNetLemmatizer
# Download necessary NLTK datasets
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
stop = set(stopwords.words('english'))
lemma = WordNetLemmatizer()

def preprocess(text):
    return " ".join(lemma.lemmatize(word) for word in text.lower().split() if word not in stop)

data['processed_text'] = data['question_text'].apply(preprocess)

# %%
data['processed_text']
# Out:
# 0         (a) number case came notice regard fighting qu...
# 1         (a) salient feature community radio station (c...
# 2         (a) whether india international skill centre (...
# 3         minister housing urban affair pleased state: (...
# 4         (a) whether government proposes carry quarterl...
#                                 ...
# 298288    (a) whether data sharing policy different stat...
# 298289    (a) present status various ongoing railway pro...
# 298290    (a) whether government tried ass profitability...
# 298291    (a) whether government received recommendation...
# 298292    (a) detail number case pending madhya pradesh ...
# Name: processed_text, Length: 298171, dtype: object

# %%
# using a subset of the data
data_sub = data.head(5)

def classify_text(text):
    # Perform classification
    results = classifier(text, labels, multi_label=True)
    # Return the labels and scores
    return results['labels'], results['scores']

# Apply the classification function to each row in 'processed_text'
data_sub['classification_results'] = data_sub['processed_text'].apply(lambda x: classify_text(x))
# Out:
# <ipython-input-16-3539c687c60b>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sub['classification_results'] = data_sub['processed_text'].apply(lambda x: classify_text(x))

# %%
# extracting the top category and score
data_sub['top_category'] = data_sub['classification_results'].apply(lambda x: x[0][0] if x else None)
data_sub['top_category_score'] = data_sub['classification_results'].apply(lambda x: x[1][0] if x else None)
# Out:
# <ipython-input-17-f91578ab4632>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sub['top_category'] = data_sub['classification_results'].apply(lambda x: x[0][0] if x else None)
# <ipython-input-17-f91578ab4632>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sub['top_category_score'] = data_sub['classification_results'].apply(lambda x: x[1][0] if x else None)

# %%
data_sub.head()
# Out:
#          id                 date ls_number  \
# 0  10173416  2017-08-02T00:00:00        16
# 1  10173216  2017-08-02T00:00:00        16
# 2  10173116  2017-08-02T00:00:00        16
# 3  10173016  2017-08-02T00:00:00        16
# 4  10172916  2017-08-02T00:00:00        16
#
#                                  ministry question_type  \
# 0                                Railways     Unstarred
# 1            Information and Broadcasting     Unstarred
# 2  Skill Development and Entrepreneurship     Unstarred
# 3               Housing and Urban Affairs     Unstarred
# 4                        Minority Affairs     Unstarred
#
#                                        question_text  \
# 0  (a) the number of cases which came to notice w...
# 1  (a) the salient features of the Community Radi...
# 2  (a) whether the India International Skill Cent...
# 3  Will the Minister of HOUSING AND URBAN AFFAIRS...
# 4  (a) whether the Government proposes to carry o...
#
#                                          answer_text  \
# 0  MINISTER OF STATE IN THE MINISTRY OF RAILWAYS ...
# 1  THE MINISTER OF STATE OF THE MINISTRY OF INFOR...
# 2  (a) to (e) As on date 14 India International S...
# 3  THE MINISTER OF STATE IN THE MINISTRY OF HOUSI...
# 4  MINISTER OF STATE (INDEPENDENT CHARGE) FOR MIN...
#
#                                     member     party             state  \
# 0                             RAJESH VERMA       BJP     Uttar Pradesh
# 1                            B. SREERAMULU       BJP         Karnataka
# 2  MEENAKASHI LEKHI, RAVINDRA KUMAR PANDEY  BJP, BJP  Delhi, Jharkhand
# 3                              RAJENDRAN S      ADMK        Tamil Nadu
# 4                              DILIP PATEL       BJP           Gujarat
#
#          constituency constituency_type        gender  \
# 0             Sitapur               GEN          Male
# 1             Bellary                ST          Male
# 2  New delhi, Giridih          GEN, GEN  Female, Male
# 3          Viluppuram                SC          Male
# 4               Anand               GEN          Male
#
#                                 subject  \
# 0  Cases of Fighting/Quarrels in Trains
# 1               Community Radio Station
# 2      India International Skill Centre
# 3            MoU with Reckitt Benckiser
# 4                    Employment Surveys
#
#                                                 link  \
# 0  https://loksabha.nic.in/Questions/QResult15.as...
# 1  https://loksabha.nic.in/Questions/QResult15.as...
# 2  https://loksabha.nic.in/Questions/QResult15.as...
# 3  https://loksabha.nic.in/Questions/QResult15.as...
# 4  https://loksabha.nic.in/Questions/QResult15.as...
#
#                                       processed_text  \
# 0  (a) number case came notice regard fighting qu...
# 1  (a) salient feature community radio station (c...
# 2  (a) whether india international skill centre (...
# 3  minister housing urban affair pleased state: (...
# 4  (a) whether government proposes carry quarterl...
#
#                               classification_results  \
# 0  ([accountability and transparency, development...
# 1  ([programmatic representation, accountability ...
# 2  ([programmatic representation, accountability ...
# 3  ([accountability and transparency, programmati...
# 4  ([accountability and transparency, programmati...
#
#                       top_category  top_category_score
# 0  accountability and transparency            0.818371
# 1      programmatic representation            0.948672
# 2      programmatic representation            0.841730
# 3  accountability and transparency            0.912875
# 4  accountability and transparency            0.638563

# %%
df_questions = data.copy()

# %%
df_questions.head()
# Out:
#          id                 date ls_number  \
# 0  10173416  2017-08-02T00:00:00        16
# 1  10173216  2017-08-02T00:00:00        16
# 2  10173116  2017-08-02T00:00:00        16
# 3  10173016  2017-08-02T00:00:00        16
# 4  10172916  2017-08-02T00:00:00        16
#
#                                  ministry question_type  \
# 0                                Railways     Unstarred
# 1            Information and Broadcasting     Unstarred
# 2  Skill Development and Entrepreneurship     Unstarred
# 3               Housing and Urban Affairs     Unstarred
# 4                        Minority Affairs     Unstarred
#
#                                        question_text  \
# 0  (a) the number of cases which came to notice w...
# 1  (a) the salient features of the Community Radi...
# 2  (a) whether the India International Skill Cent...
# 3  Will the Minister of HOUSING AND URBAN AFFAIRS...
# 4  (a) whether the Government proposes to carry o...
#
#                                          answer_text  \
# 0  MINISTER OF STATE IN THE MINISTRY OF RAILWAYS ...
# 1  THE MINISTER OF STATE OF THE MINISTRY OF INFOR...
# 2  (a) to (e) As on date 14 India International S...
# 3  THE MINISTER OF STATE IN THE MINISTRY OF HOUSI...
# 4  MINISTER OF STATE (INDEPENDENT CHARGE) FOR MIN...
#
#                                     member     party             state  \
# 0                             RAJESH VERMA       BJP     Uttar Pradesh
# 1                            B. SREERAMULU       BJP         Karnataka
# 2  MEENAKASHI LEKHI, RAVINDRA KUMAR PANDEY  BJP, BJP  Delhi, Jharkhand
# 3                              RAJENDRAN S      ADMK        Tamil Nadu
# 4                              DILIP PATEL       BJP           Gujarat
#
#          constituency constituency_type        gender  \
# 0             Sitapur               GEN          Male
# 1             Bellary                ST          Male
# 2  New delhi, Giridih          GEN, GEN  Female, Male
# 3          Viluppuram                SC          Male
# 4               Anand               GEN          Male
#
#                                 subject  \
# 0  Cases of Fighting/Quarrels in Trains
# 1               Community Radio Station
# 2      India International Skill Centre
# 3            MoU with Reckitt Benckiser
# 4                    Employment Surveys
#
#                                                 link  \
# 0  https://loksabha.nic.in/Questions/QResult15.as...
# 1  https://loksabha.nic.in/Questions/QResult15.as...
# 2  https://loksabha.nic.in/Questions/QResult15.as...
# 3  https://loksabha.nic.in/Questions/QResult15.as...
# 4  https://loksabha.nic.in/Questions/QResult15.as...
#
#                                       processed_text
# 0  (a) number case came notice regard fighting qu...
# 1  (a) salient feature community radio station (c...
# 2  (a) whether india international skill centre (...
# 3  minister housing urban affair pleased state: (...
# 4  (a) whether government proposes carry quarterl...

# %%
df_questions = df_questions[df_questions['gender'].isin(['Male', 'Female'])]

# %%
df_questions.head()
# Out:
#          id                 date ls_number  \
# 0  10173416  2017-08-02T00:00:00        16
# 1  10173216  2017-08-02T00:00:00        16
# 3  10173016  2017-08-02T00:00:00        16
# 4  10172916  2017-08-02T00:00:00        16
# 6  10172716  2017-08-02T00:00:00        16
#
#                                  ministry question_type  \
# 0                                Railways     Unstarred
# 1            Information and Broadcasting     Unstarred
# 3               Housing and Urban Affairs     Unstarred
# 4                        Minority Affairs     Unstarred
# 6  Skill Development and Entrepreneurship     Unstarred
#
#                                        question_text  \
# 0  (a) the number of cases which came to notice w...
# 1  (a) the salient features of the Community Radi...
# 3  Will the Minister of HOUSING AND URBAN AFFAIRS...
# 4  (a) whether the Government proposes to carry o...
# 6  (a) whether the Government has framed rules an...
#
#                                          answer_text         member party  \
# 0  MINISTER OF STATE IN THE MINISTRY OF RAILWAYS ...   RAJESH VERMA   BJP
# 1  THE MINISTER OF STATE OF THE MINISTRY OF INFOR...  B. SREERAMULU   BJP
# 3  THE MINISTER OF STATE IN THE MINISTRY OF HOUSI...    RAJENDRAN S  ADMK
# 4  MINISTER OF STATE (INDEPENDENT CHARGE) FOR MIN...    DILIP PATEL   BJP
# 6  (a) to (e) The Ministry of Skill Development a...      ANJU BALA   BJP
#
#            state constituency constituency_type  gender  \
# 0  Uttar Pradesh      Sitapur               GEN    Male
# 1      Karnataka      Bellary                ST    Male
# 3     Tamil Nadu   Viluppuram                SC    Male
# 4        Gujarat        Anand               GEN    Male
# 6  Uttar Pradesh      Misrikh                SC  Female
#
#                                       subject  \
# 0        Cases of Fighting/Quarrels in Trains
# 1                     Community Radio Station
# 3                  MoU with Reckitt Benckiser
# 4                          Employment Surveys
# 6  Retired Government Officers as Consultants
#
#                                                 link  \
# 0  https://loksabha.nic.in/Questions/QResult15.as...
# 1  https://loksabha.nic.in/Questions/QResult15.as...
# 3  https://loksabha.nic.in/Questions/QResult15.as...
# 4  https://loksabha.nic.in/Questions/QResult15.as...
# 6  https://loksabha.nic.in/Questions/QResult15.as...
#
#                                       processed_text
# 0  (a) number case came notice regard fighting qu...
# 1  (a) salient feature community radio station (c...
# 3  minister housing urban affair pleased state: (...
# 4  (a) whether government proposes carry quarterl...
# 6  (a) whether government framed rule guideline h...

# %%
df_constituency = pd.read_csv("/content/TCPD_GE_All_States_2024-1-27.csv")
# Out:
# <ipython-input-23-32a92bbbc6a9>:1: DtypeWarning: Columns (17,36,37,38,39,40,41,42,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_constituency = pd.read_csv("/content/TCPD_GE_All_States_2024-1-27.csv")

# %%
df_constituency.head()
# Out:
#                   State_Name  Assembly_No  Constituency_No  Year  month  \
# 0  Andaman_&_Nicobar_Islands           17                1  2019    4.0
# 1  Andaman_&_Nicobar_Islands           17                1  2019    4.0
# 2  Andaman_&_Nicobar_Islands           17                1  2019    4.0
# 3  Andaman_&_Nicobar_Islands           17                1  2019    4.0
# 4  Andaman_&_Nicobar_Islands           17                1  2019    4.0
#
#    Poll_No  DelimID  Position              Candidate Sex  ... No_Terms  \
# 0        0        4         1     KULDEEP RAI SHARMA   M  ...      1.0
# 1        0        4         2           VISHAL JOLLY   M  ...      0.0
# 2        0        4         3  PARITOSH KUMAR HALDAR   M  ...      0.0
# 3        0        4         4         SANJAY MESHACK   M  ...      0.0
# 4        0        4         5           PRAKASH MINJ   M  ...      0.0
#
#    Turncoat Incumbent  Recontest       MyNeta_education  \
# 0     False     False       True  Graduate Professional
# 1     False     False      False  Graduate Professional
# 2     False     False      False          Post Graduate
# 3     False     False       True              12th Pass
# 4     False     False      False          Post Graduate
#
#                        TCPD_Prof_Main TCPD_Prof_Main_Desc TCPD_Prof_Second  \
# 0                            Business                 NaN      Social Work
# 1  Liberal Profession or Professional              Lawyer              NaN
# 2                         Agriculture                 NaN              NaN
# 3                            Business                 NaN         Politics
# 4                         Social Work                 NaN              NaN
#
#    TCPD_Prof_Second_Desc            Election_Type
# 0                    NaN  Lok Sabha Election (GE)
# 1                    NaN  Lok Sabha Election (GE)
# 2                    NaN  Lok Sabha Election (GE)
# 3    Municipality Member  Lok Sabha Election (GE)
# 4                    NaN  Lok Sabha Election (GE)
#
# [5 rows x 45 columns]

# %%
df_constituency = df_constituency[df_constituency['Position'] == 1]

# %%
df_constituency.head()
# Out:
#                    State_Name  Assembly_No  Constituency_No  Year  month  \
# 0   Andaman_&_Nicobar_Islands           17                1  2019    4.0
# 16             Andhra_Pradesh           17                1  2019    4.0
# 27             Andhra_Pradesh           17                2  2019    4.0
# 37             Andhra_Pradesh           17                3  2019    4.0
# 52             Andhra_Pradesh           17                4  2019    4.0
#
#     Poll_No  DelimID  Position                  Candidate Sex  ... No_Terms  \
# 0         0        4         1         KULDEEP RAI SHARMA   M  ...      1.0
# 16        0        4         1           GODDETI. MADHAVI   F  ...      1.0
# 27        0        4         1  KINJARAPU RAM MOHAN NAIDU   M  ...      1.0
# 37        0        4         1     Bellana Chandra Sekhar   M  ...      1.0
# 52        0        4         1        M V V SATYANARAYANA   M  ...      1.0
#
#     Turncoat Incumbent  Recontest       MyNeta_education TCPD_Prof_Main  \
# 0      False     False       True  Graduate Professional       Business
# 16     False     False      False  Graduate Professional    Social Work
# 27     False     False      False          Post Graduate       Politics
# 37     False     False      False  Graduate Professional       Business
# 52     False     False      False              10th Pass       Business
#
#                                   TCPD_Prof_Main_Desc  \
# 0                                                 NaN
# 16                                                NaN
# 27                                                NaN
# 37                                                NaN
# 52  Real Estate or Builder or Developer or Constru...
#
#                       TCPD_Prof_Second  TCPD_Prof_Second_Desc  \
# 0                          Social Work                    NaN
# 16                                 NaN                    NaN
# 27                                 NaN                    NaN
# 37  Liberal Profession or Professional                 Lawyer
# 52           Salaried Work or Employed    Managerial Position
#
#               Election_Type
# 0   Lok Sabha Election (GE)
# 16  Lok Sabha Election (GE)
# 27  Lok Sabha Election (GE)
# 37  Lok Sabha Election (GE)
# 52  Lok Sabha Election (GE)
#
# [5 rows x 45 columns]

# %%
# lowercase
df_questions['constituency'] = df_questions['constituency'].str.lower()
df_constituency['Constituency_Name'] = df_constituency['Constituency_Name'].str.lower()

# %%
df_questions.head()
# Out:
#          id                 date ls_number  \
# 0  10173416  2017-08-02T00:00:00        16
# 1  10173216  2017-08-02T00:00:00        16
# 3  10173016  2017-08-02T00:00:00        16
# 4  10172916  2017-08-02T00:00:00        16
# 6  10172716  2017-08-02T00:00:00        16
#
#                                  ministry question_type  \
# 0                                Railways     Unstarred
# 1            Information and Broadcasting     Unstarred
# 3               Housing and Urban Affairs     Unstarred
# 4                        Minority Affairs     Unstarred
# 6  Skill Development and Entrepreneurship     Unstarred
#
#                                        question_text  \
# 0  (a) the number of cases which came to notice w...
# 1  (a) the salient features of the Community Radi...
# 3  Will the Minister of HOUSING AND URBAN AFFAIRS...
# 4  (a) whether the Government proposes to carry o...
# 6  (a) whether the Government has framed rules an...
#
#                                          answer_text         member party  \
# 0  MINISTER OF STATE IN THE MINISTRY OF RAILWAYS ...   RAJESH VERMA   BJP
# 1  THE MINISTER OF STATE OF THE MINISTRY OF INFOR...  B. SREERAMULU   BJP
# 3  THE MINISTER OF STATE IN THE MINISTRY OF HOUSI...    RAJENDRAN S  ADMK
# 4  MINISTER OF STATE (INDEPENDENT CHARGE) FOR MIN...    DILIP PATEL   BJP
# 6  (a) to (e) The Ministry of Skill Development a...      ANJU BALA   BJP
#
#            state constituency constituency_type  gender  \
# 0  Uttar Pradesh      sitapur               GEN    Male
# 1      Karnataka      bellary                ST    Male
# 3     Tamil Nadu   viluppuram                SC    Male
# 4        Gujarat        anand               GEN    Male
# 6  Uttar Pradesh      misrikh                SC  Female
#
#                                       subject  \
# 0        Cases of Fighting/Quarrels in Trains
# 1                     Community Radio Station
# 3                  MoU with Reckitt Benckiser
# 4                          Employment Surveys
# 6  Retired Government Officers as Consultants
#
#                                                 link  \
# 0  https://loksabha.nic.in/Questions/QResult15.as...
# 1  https://loksabha.nic.in/Questions/QResult15.as...
# 3  https://loksabha.nic.in/Questions/QResult15.as...
# 4  https://loksabha.nic.in/Questions/QResult15.as...
# 6  https://loksabha.nic.in/Questions/QResult15.as...
#
#                                       processed_text
# 0  (a) number case came notice regard fighting qu...
# 1  (a) salient feature community radio station (c...
# 3  minister housing urban affair pleased state: (...
# 4  (a) whether government proposes carry quarterl...
# 6  (a) whether government framed rule guideline h...

# %%
df_constituency['Constituency_Name']
# Out:
# 0        andaman & nicobar islands
# 16                           aruku
# 27                      srikakulam
# 37                    vizianagaram
# 52                   visakhapatnam
#                    ...
# 91655                     amravati
# 91657                       tumkur
# 91660                 chikballapur
# 91662                    bangalore
# 91665                      hathras
# Name: Constituency_Name, Length: 8291, dtype: object

# %%
# 'date' is a string column
df_questions['date'] = pd.to_datetime(df_questions['date'])
df_questions['Year'] = df_questions['date'].dt.year  # Extract year

# %%
df_constituency['Year'] = df_constituency['Year'].astype(int)

# %%
# Standardize gender coding in df_questions
gender_map = {'Male': 'M', 'Female': 'F'}
df_questions['gender'] = df_questions['gender'].replace(gender_map)

# %%
# Trying match identifiers

df_questions['constituency'] = df_questions['constituency'].str.lower().str.replace(' ', '_')
df_questions['constituency_year'] = df_questions['constituency'] + '_' + df_questions['Year'].astype(str)

df_constituency['Constituency_Name'] = df_constituency['Constituency_Name'].str.lower().str.replace(' ', '_')
df_constituency['constituency_year'] = df_constituency['Constituency_Name'] + '_' + df_constituency['Year'].astype(str)

# %%
df_questions.head()
# Out:
#          id       date ls_number                                ministry  \
# 0  10173416 2017-08-02        16                                Railways
# 1  10173216 2017-08-02        16            Information and Broadcasting
# 3  10173016 2017-08-02        16               Housing and Urban Affairs
# 4  10172916 2017-08-02        16                        Minority Affairs
# 6  10172716 2017-08-02        16  Skill Development and Entrepreneurship
#
#   question_type                                      question_text  \
# 0     Unstarred  (a) the number of cases which came to notice w...
# 1     Unstarred  (a) the salient features of the Community Radi...
# 3     Unstarred  Will the Minister of HOUSING AND URBAN AFFAIRS...
# 4     Unstarred  (a) whether the Government proposes to carry o...
# 6     Unstarred  (a) whether the Government has framed rules an...
#
#                                          answer_text         member party  \
# 0  MINISTER OF STATE IN THE MINISTRY OF RAILWAYS ...   RAJESH VERMA   BJP
# 1  THE MINISTER OF STATE OF THE MINISTRY OF INFOR...  B. SREERAMULU   BJP
# 3  THE MINISTER OF STATE IN THE MINISTRY OF HOUSI...    RAJENDRAN S  ADMK
# 4  MINISTER OF STATE (INDEPENDENT CHARGE) FOR MIN...    DILIP PATEL   BJP
# 6  (a) to (e) The Ministry of Skill Development a...      ANJU BALA   BJP
#
#            state constituency constituency_type gender  \
# 0  Uttar Pradesh      sitapur               GEN      M
# 1      Karnataka      bellary                ST      M
# 3     Tamil Nadu   viluppuram                SC      M
# 4        Gujarat        anand               GEN      M
# 6  Uttar Pradesh      misrikh                SC      F
#
#                                       subject  \
# 0        Cases of Fighting/Quarrels in Trains
# 1                     Community Radio Station
# 3                  MoU with Reckitt Benckiser
# 4                          Employment Surveys
# 6  Retired Government Officers as Consultants
#
#                                                 link  \
# 0  https://loksabha.nic.in/Questions/QResult15.as...
# 1  https://loksabha.nic.in/Questions/QResult15.as...
# 3  https://loksabha.nic.in/Questions/QResult15.as...
# 4  https://loksabha.nic.in/Questions/QResult15.as...
# 6  https://loksabha.nic.in/Questions/QResult15.as...
#
#                                       processed_text  Year constituency_year
# 0  (a) number case came notice regard fighting qu...  2017      sitapur_2017
# 1  (a) salient feature community radio station (c...  2017      bellary_2017
# 3  minister housing urban affair pleased state: (...  2017   viluppuram_2017
# 4  (a) whether government proposes carry quarterl...  2017        anand_2017
# 6  (a) whether government framed rule guideline h...  2017      misrikh_2017

# %%
df_constituency.head()
# Out:
#                    State_Name  Assembly_No  Constituency_No  Year  month  \
# 0   Andaman_&_Nicobar_Islands           17                1  2019    4.0
# 16             Andhra_Pradesh           17                1  2019    4.0
# 27             Andhra_Pradesh           17                2  2019    4.0
# 37             Andhra_Pradesh           17                3  2019    4.0
# 52             Andhra_Pradesh           17                4  2019    4.0
#
#     Poll_No  DelimID  Position                  Candidate Sex  ... Turncoat  \
# 0         0        4         1         KULDEEP RAI SHARMA   M  ...    False
# 16        0        4         1           GODDETI. MADHAVI   F  ...    False
# 27        0        4         1  KINJARAPU RAM MOHAN NAIDU   M  ...    False
# 37        0        4         1     Bellana Chandra Sekhar   M  ...    False
# 52        0        4         1        M V V SATYANARAYANA   M  ...    False
#
#     Incumbent Recontest       MyNeta_education  TCPD_Prof_Main  \
# 0       False      True  Graduate Professional        Business
# 16      False     False  Graduate Professional     Social Work
# 27      False     False          Post Graduate        Politics
# 37      False     False  Graduate Professional        Business
# 52      False     False              10th Pass        Business
#
#                                   TCPD_Prof_Main_Desc  \
# 0                                                 NaN
# 16                                                NaN
# 27                                                NaN
# 37                                                NaN
# 52  Real Estate or Builder or Developer or Constru...
#
#                       TCPD_Prof_Second TCPD_Prof_Second_Desc  \
# 0                          Social Work                   NaN
# 16                                 NaN                   NaN
# 27                                 NaN                   NaN
# 37  Liberal Profession or Professional                Lawyer
# 52           Salaried Work or Employed   Managerial Position
#
#               Election_Type               constituency_year
# 0   Lok Sabha Election (GE)  andaman_&_nicobar_islands_2019
# 16  Lok Sabha Election (GE)                      aruku_2019
# 27  Lok Sabha Election (GE)                 srikakulam_2019
# 37  Lok Sabha Election (GE)               vizianagaram_2019
# 52  Lok Sabha Election (GE)              visakhapatnam_2019
#
# [5 rows x 46 columns]

# %%
# Merging the datasets on the unique identifier
df_merged = pd.merge(df_questions, df_constituency, on='constituency_year', how='right')

# %%
df_merged.head()
# Out:
#           id       date ls_number               ministry question_type  \
# 0        NaN        NaT       NaN                    NaN           NaN
# 1        NaN        NaT       NaN                    NaN           NaN
# 2  318415516 2019-02-04        16  Labour and Employment     Unstarred
# 3   31751616 2019-02-04        16  Labour and Employment       Starred
# 4  317821216 2019-02-04        16  Labour and Employment     Unstarred
#
#                                        question_text  \
# 0                                                NaN
# 1                                                NaN
# 2  (a) whether the Government has set sectoral jo...
# 3  (a) whether it is true that the unemployment r...
# 4  (a)whether the Government is aware of the skew...
#
#                                          answer_text  \
# 0                                                NaN
# 1                                                NaN
# 2  MINISTER OF STATE (IC) FOR LABOUR AND EMPLOYME...
# 3  MINISTER OF STATE (IC) FOR LABOUR AND EMPLOYME...
# 4  MINISTER OF STATE (IC) FOR LABOUR AND EMPLOYME...
#
#                      member party           state  ... No_Terms Turncoat  \
# 0                       NaN   NaN             NaN  ...      1.0    False
# 1                       NaN   NaN             NaN  ...      1.0    False
# 2  RAMMOHAN NAIDU KINJARAPU   TDP  Andhra Pradesh  ...      1.0    False
# 3  RAMMOHAN NAIDU KINJARAPU   TDP  Andhra Pradesh  ...      1.0    False
# 4  RAMMOHAN NAIDU KINJARAPU   TDP  Andhra Pradesh  ...      1.0    False
#
#   Incumbent Recontest       MyNeta_education TCPD_Prof_Main  \
# 0     False      True  Graduate Professional       Business
# 1     False     False  Graduate Professional    Social Work
# 2     False     False          Post Graduate       Politics
# 3     False     False          Post Graduate       Politics
# 4     False     False          Post Graduate       Politics
#
#    TCPD_Prof_Main_Desc TCPD_Prof_Second TCPD_Prof_Second_Desc  \
# 0                  NaN      Social Work                   NaN
# 1                  NaN              NaN                   NaN
# 2                  NaN              NaN                   NaN
# 3                  NaN              NaN                   NaN
# 4                  NaN              NaN                   NaN
#
#              Election_Type
# 0  Lok Sabha Election (GE)
# 1  Lok Sabha Election (GE)
# 2  Lok Sabha Election (GE)
# 3  Lok Sabha Election (GE)
# 4  Lok Sabha Election (GE)
#
# [5 rows x 63 columns]

# %%
print(df_merged.isnull().sum())
# Out:
# id                        6731
# date                      6731
# ls_number                 6731
# ministry                  6731
# question_type             6731
#                          ...
# TCPD_Prof_Main            7444
# TCPD_Prof_Main_Desc      29178
# TCPD_Prof_Second         30902
# TCPD_Prof_Second_Desc    34267
# Election_Type                0
# Length: 63, dtype: int64

# %%
df_constituency.shape[0]
# Out:
# 8291

# %%
df_merged.shape[0]
# Out:
# 35294

# %%
df_merged = df_merged.drop(columns=['TCPD_Prof_Main', 'TCPD_Prof_Main_Desc', 'TCPD_Prof_Second',
                                    'TCPD_Prof_Second_Desc', 'Election_Type',
                                    ])

# %%
df_merged = df_merged[df_merged['question_text'].notna()]

# %%
df_merged.head()
# Out:
#           id       date ls_number               ministry question_type  \
# 2  318415516 2019-02-04        16  Labour and Employment     Unstarred
# 3   31751616 2019-02-04        16  Labour and Employment       Starred
# 4  317821216 2019-02-04        16  Labour and Employment     Unstarred
# 5  313857616 2019-02-06        16                Defence     Unstarred
# 6  386106216 2019-02-08        16                Finance     Unstarred
#
#                                        question_text  \
# 2  (a) whether the Government has set sectoral jo...
# 3  (a) whether it is true that the unemployment r...
# 4  (a)whether the Government is aware of the skew...
# 5  (a) whether it is true that the capex in defen...
# 6  (a) whether the public sector asset expansion ...
#
#                                          answer_text  \
# 2  MINISTER OF STATE (IC) FOR LABOUR AND EMPLOYME...
# 3  MINISTER OF STATE (IC) FOR LABOUR AND EMPLOYME...
# 4  MINISTER OF STATE (IC) FOR LABOUR AND EMPLOYME...
# 5  MINISTER OF STATE (DR. SUBHASH BHAMRE) IN THE ...
# 6  THE MINISTER OF STATE FOR FINANCE (SHRI PON RA...
#
#                      member party           state  ... Last_Party  \
# 2  RAMMOHAN NAIDU KINJARAPU   TDP  Andhra Pradesh  ...        NaN
# 3  RAMMOHAN NAIDU KINJARAPU   TDP  Andhra Pradesh  ...        NaN
# 4  RAMMOHAN NAIDU KINJARAPU   TDP  Andhra Pradesh  ...        NaN
# 5  RAMMOHAN NAIDU KINJARAPU   TDP  Andhra Pradesh  ...        NaN
# 6  RAMMOHAN NAIDU KINJARAPU   TDP  Andhra Pradesh  ...        NaN
#
#   Last_Party_ID Last_Constituency_Name Same_Constituency Same_Party No_Terms  \
# 2           NaN                    NaN               NaN        NaN      1.0
# 3           NaN                    NaN               NaN        NaN      1.0
# 4           NaN                    NaN               NaN        NaN      1.0
# 5           NaN                    NaN               NaN        NaN      1.0
# 6           NaN                    NaN               NaN        NaN      1.0
#
#    Turncoat Incumbent Recontest  MyNeta_education
# 2     False     False     False     Post Graduate
# 3     False     False     False     Post Graduate
# 4     False     False     False     Post Graduate
# 5     False     False     False     Post Graduate
# 6     False     False     False     Post Graduate
#
# [5 rows x 58 columns]

# %%
df_merged.to_csv('merged_dataset.csv', index=False)

# %%
# checking for treatment constituencies
df_constituency_sorted = df_constituency.sort_values(by=['Constituency_No', 'Year'])

# Identify changes in gender representation
df_constituency_sorted['previous_sex'] = df_constituency_sorted.groupby('Constituency_No')['Sex'].shift(1)
df_constituency_sorted = df_constituency_sorted.dropna(subset=['previous_sex'])
df_constituency_sorted['gender_change'] = df_constituency_sorted['Sex'] != df_constituency_sorted['previous_sex']


# Filter for treated constituencies
treated_constituencies = df_constituency_sorted[df_constituency_sorted['gender_change']]

# %%
df_constituency_sorted
# Out:
#              State_Name  Assembly_No  Constituency_No  Year  month  Poll_No  \
# 89778             Assam            3                1  1962    2.0        0
# 89819             Bihar            3                1  1962    2.0        0
# 90052             Delhi            3                1  1962    2.0        0
# 90080           Gujarat            3                1  1962    2.0        0
# 90148  Himachal_Pradesh            3                1  1962    2.0        0
# ...                 ...          ...              ...   ...    ...      ...
# 70663     Uttar_Pradesh            9               85  1989   11.0        0
# 63980     Uttar_Pradesh           10               85  1991    5.0        0
# 55225     Uttar_Pradesh           11               85  1996    4.0        0
# 41396     Uttar_Pradesh           12               85  1998    3.0        0
# 36383     Uttar_Pradesh           13               85  1999    9.0        0
#
#        DelimID  Position                       Candidate Sex  ... Recontest  \
# 89778        1         1                  JYOTSNA CHANDA   F  ...     False
# 89819        1         1               KAMAL NATH TEWARI   M  ...     False
# 90052        1         1               MEHR CHAND KHANNA   M  ...     False
# 90080        1         1  M. K. S. HIMATSINHJI VIJARAJJI   M  ...     False
# 90148        1         1                   CHATTAR SINGH   M  ...     False
# ...        ...       ...                             ...  ..  ...       ...
# 70663        3         1                    JAGPAL SINGH   M  ...     False
# 63980        3         1                       RAM SINGH   M  ...     False
# 55225        3         1                    HARPAL SATHI   M  ...     False
# 41396        3         1              HARPAL SINGH SATHI   M  ...      True
# 36383        3         1              Harpal Singh Sathi   M  ...      True
#
#        MyNeta_education TCPD_Prof_Main  TCPD_Prof_Main_Desc  TCPD_Prof_Second  \
# 89778               NaN            NaN                  NaN               NaN
# 89819               NaN            NaN                  NaN               NaN
# 90052               NaN            NaN                  NaN               NaN
# 90080               NaN            NaN                  NaN               NaN
# 90148               NaN            NaN                  NaN               NaN
# ...                 ...            ...                  ...               ...
# 70663               NaN            NaN                  NaN               NaN
# 63980               NaN            NaN                  NaN               NaN
# 55225               NaN            NaN                  NaN               NaN
# 41396               NaN            NaN                  NaN               NaN
# 36383               NaN            NaN                  NaN               NaN
#
#       TCPD_Prof_Second_Desc            Election_Type constituency_year  \
# 89778                   NaN  Lok Sabha Election (GE)       cachar_1962
# 89819                   NaN  Lok Sabha Election (GE)       bagaha_1962
# 90052                   NaN  Lok Sabha Election (GE)    new_delhi_1962
# 90080                   NaN  Lok Sabha Election (GE)        kutch_1962
# 90148                   NaN  Lok Sabha Election (GE)       chamba_1962
# ...                     ...                      ...               ...
# 70663                   NaN  Lok Sabha Election (GE)      hardwar_1989
# 63980                   NaN  Lok Sabha Election (GE)      hardwar_1991
# 55225                   NaN  Lok Sabha Election (GE)      hardwar_1996
# 41396                   NaN  Lok Sabha Election (GE)      hardwar_1998
# 36383                   NaN  Lok Sabha Election (GE)      hardwar_1999
#
#        previous_sex  gender_change
# 89778             M           True
# 89819             F           True
# 90052             M          False
# 90080             M          False
# 90148             M          False
# ...             ...            ...
# 70663             M          False
# 63980             M          False
# 55225             M          False
# 41396             M          False
# 36383             M          False
#
# [8143 rows x 48 columns]

# %%
df_constituency_sorted.shape[0]
# Out:
# 8143

# %%
treated_constituencies.shape[0]
# Out:
# 1224

# %%
treated_constituencies
# Out:
#           State_Name  Assembly_No  Constituency_No  Year  month  Poll_No  \
# 89778          Assam            3                1  1962    2.0        0
# 89819          Bihar            3                1  1962    2.0        0
# 91619    West_Bengal            3                1  1963    NaN        1
# 87276          Assam            4                1  1967    2.0        0
# 87323          Bihar            4                1  1967    2.0        0
# ...              ...          ...              ...   ...    ...      ...
# 89293  Uttar_Pradesh            4               80  1967    2.0        0
# 81101  Uttar_Pradesh            7               80  1980    1.0        0
# 70596  Uttar_Pradesh            9               80  1989   11.0        0
# 81139  Uttar_Pradesh            7               83  1980    1.0        0
# 76027  Uttar_Pradesh            8               83  1984   12.0        0
#
#        DelimID  Position          Candidate  Sex  ... Recontest  \
# 89778        1         1     JYOTSNA CHANDA    F  ...     False
# 89819        1         1  KAMAL NATH TEWARI    M  ...     False
# 91619        1         1         P.C.BARMAN  NaN  ...     False
# 87276        2         1          J. CHANDA    F  ...      True
# 87323        2         1            B. RAUT    M  ...      True
# ...        ...       ...                ...  ...  ...       ...
# 89293        2         1        M.S. BHARTI    M  ...     False
# 81101        3         1     MOHSINA KIDWAI    F  ...      True
# 70596        3         1         HARISH PAL    M  ...     False
# 81139        3         1        GYATRI DEVI    F  ...     False
# 76027        3         1       AKHTAR HASAN    M  ...     False
#
#        MyNeta_education TCPD_Prof_Main  TCPD_Prof_Main_Desc  TCPD_Prof_Second  \
# 89778               NaN            NaN                  NaN               NaN
# 89819               NaN            NaN                  NaN               NaN
# 91619               NaN            NaN                  NaN               NaN
# 87276               NaN            NaN                  NaN               NaN
# 87323               NaN            NaN                  NaN               NaN
# ...                 ...            ...                  ...               ...
# 89293               NaN            NaN                  NaN               NaN
# 81101               NaN            NaN                  NaN               NaN
# 70596               NaN            NaN                  NaN               NaN
# 81139               NaN            NaN                  NaN               NaN
# 76027               NaN            NaN                  NaN               NaN
#
#       TCPD_Prof_Second_Desc            Election_Type constituency_year  \
# 89778                   NaN  Lok Sabha Election (GE)       cachar_1962
# 89819                   NaN  Lok Sabha Election (GE)       bagaha_1962
# 91619                   NaN  Lok Sabha Election (GE)        cooch_1963
# 87276                   NaN  Lok Sabha Election (GE)       cachar_1967
# 87323                   NaN  Lok Sabha Election (GE)       bagaha_1967
# ...                     ...                      ...               ...
# 89293                   NaN  Lok Sabha Election (GE)       meerut_1967
# 81101                   NaN  Lok Sabha Election (GE)       meerut_1980
# 70596                   NaN  Lok Sabha Election (GE)       meerut_1989
# 81139                   NaN  Lok Sabha Election (GE)      kairana_1980
# 76027                   NaN  Lok Sabha Election (GE)      kairana_1984
#
#        previous_sex  gender_change
# 89778             M           True
# 89819             F           True
# 91619             M           True
# 87276             M           True
# 87323             F           True
# ...             ...            ...
# 89293             F           True
# 81101             M           True
# 70596             F           True
# 81139             M           True
# 76027             F           True
#
# [1224 rows x 48 columns]

# %%
# Merging the datasets on the unique identifier
df_merged_final = pd.merge(df_questions, df_constituency_sorted, on='constituency_year', how='right')

# %%
df_merged_final.shape[0]
# Out:
# 35129

# %%
df_merged_final = df_merged_final[df_merged_final['question_text'].notna()]
df_merged_final.shape[0]
# Out:
# 28543

# %%
df_merged_final.head()
# Out:
#            id       date ls_number           ministry question_type  \
# 304  17350913 1999-12-09        13  Rural Development     Unstarred
# 306  17354313 1999-12-01        13     Prime Minister     Unstarred
# 320  17353813 1999-12-02        13  Rural Development     Unstarred
# 324  10021313 2004-02-04        13           Shipping     Unstarred
# 325  16344514 2004-08-16        14            Tourism     Unstarred
#
#                                          question_text  \
# 304  (a) whether any scheme is under consideation o...
# 306  (a) whether the Government propose to conduct ...
# 320  (a) The guidelines and directions issued by th...
# 324  (a) the time when the Sompen Hospital Ship arr...
# 325  (a) whether the Government has any proposal to...
#
#                                            answer_text                member  \
# 304  MINISTER OF STATE FOR RURAL DEVELOPMENT (SHRI ...  ABDUL RASHID SHAHEEN
# 306  THE MINISTER OF STATE IN THE DEPARTMENT OF ATO...           T. GOVINDAN
# 320  Minister of State for RURAL DEVELOPMENT (SHRI ...       SAMAR CHOWDHURY
# 324  MINISTER OF STATE IN THE MINISTRY OF SHIPPING ...       BISHNU PADA RAY
# 325  MINISTER OF STATE FOR TOURISM (INDEPENDENT CHA...     MANORANJAN BHAKTA
#
#     party                      state  ... Incumbent Recontest  \
# 304   JKN            Jammu & Kashmir  ...     False     False
# 306   CPM                     Kerala  ...      True      True
# 320   CPM                    Tripura  ...      True      True
# 324   BJP  Andaman & Nicobar Islands  ...     False      True
# 325   INC  Andaman & Nicobar Islands  ...     False      True
#
#     MyNeta_education TCPD_Prof_Main TCPD_Prof_Main_Desc TCPD_Prof_Second  \
# 304              NaN            NaN                 NaN              NaN
# 306              NaN            NaN                 NaN              NaN
# 320              NaN            NaN                 NaN              NaN
# 324    Post Graduate          Other                 NaN              NaN
# 325    Post Graduate          Other                 NaN              NaN
#
#      TCPD_Prof_Second_Desc            Election_Type previous_sex  \
# 304                    NaN  Lok Sabha Election (GE)            M
# 306                    NaN  Lok Sabha Election (GE)            M
# 320                    NaN  Lok Sabha Election (GE)            M
# 324                    NaN  Lok Sabha Election (GE)            M
# 325                    NaN  Lok Sabha Election (GE)            M
#
#      gender_change
# 304          False
# 306          False
# 320          False
# 324          False
# 325          False
#
# [5 rows x 65 columns]

# %%
df_merged_final.to_csv('merged_dataset_final.csv', index=False)

# %%
df_merged_final['processed_text']
# Out:
# 304      (a) whether scheme consideation government all...
# 306      (a) whether government propose conduct nuclear...
# 320      (a) guideline direction issued planning commis...
# 324      (a) time sompen hospital ship arrived port bla...
# 325      (a) whether government proposal develop touris...
#                                ...
# 35059    (a) whether employee railway covered health sc...
# 35060    (a) whether deforestation/felling tree going v...
# 35061    (a) detail step taken government conservation ...
# 35074    (a) whether government aware five star hotel m...
# 35075    (a) whether government proposes promote nation...
# Name: processed_text, Length: 28543, dtype: object

# %%
# carrying out the zero shot classification on this data
df_merged_final['classification_results'] = df_merged_final['processed_text'].apply(lambda x: classify_text(x))
# extracting the top category and score
df_merged_final['top_category'] = df_merged_final['classification_results'].apply(lambda x: x[0][0] if x else None)
df_merged_final['top_category_score'] = df_merged_final['classification_results'].apply(lambda x: x[1][0] if x else None)

# %%
df_merged_final.head()
# Out:
#            id       date ls_number           ministry question_type  \
# 304  17350913 1999-12-09        13  Rural Development     Unstarred
# 306  17354313 1999-12-01        13     Prime Minister     Unstarred
# 320  17353813 1999-12-02        13  Rural Development     Unstarred
# 324  10021313 2004-02-04        13           Shipping     Unstarred
# 325  16344514 2004-08-16        14            Tourism     Unstarred
#
#                                          question_text  \
# 304  (a) whether any scheme is under consideation o...
# 306  (a) whether the Government propose to conduct ...
# 320  (a) The guidelines and directions issued by th...
# 324  (a) the time when the Sompen Hospital Ship arr...
# 325  (a) whether the Government has any proposal to...
#
#                                            answer_text                member  \
# 304  MINISTER OF STATE FOR RURAL DEVELOPMENT (SHRI ...  ABDUL RASHID SHAHEEN
# 306  THE MINISTER OF STATE IN THE DEPARTMENT OF ATO...           T. GOVINDAN
# 320  Minister of State for RURAL DEVELOPMENT (SHRI ...       SAMAR CHOWDHURY
# 324  MINISTER OF STATE IN THE MINISTRY OF SHIPPING ...       BISHNU PADA RAY
# 325  MINISTER OF STATE FOR TOURISM (INDEPENDENT CHA...     MANORANJAN BHAKTA
#
#     party                      state  ... TCPD_Prof_Main TCPD_Prof_Main_Desc  \
# 304   JKN            Jammu & Kashmir  ...            NaN                 NaN
# 306   CPM                     Kerala  ...            NaN                 NaN
# 320   CPM                    Tripura  ...            NaN                 NaN
# 324   BJP  Andaman & Nicobar Islands  ...          Other                 NaN
# 325   INC  Andaman & Nicobar Islands  ...          Other                 NaN
#
#     TCPD_Prof_Second TCPD_Prof_Second_Desc            Election_Type  \
# 304              NaN                   NaN  Lok Sabha Election (GE)
# 306              NaN                   NaN  Lok Sabha Election (GE)
# 320              NaN                   NaN  Lok Sabha Election (GE)
# 324              NaN                   NaN  Lok Sabha Election (GE)
# 325              NaN                   NaN  Lok Sabha Election (GE)
#
#     previous_sex  gender_change  \
# 304            M          False
# 306            M          False
# 320            M          False
# 324            M          False
# 325            M          False
#
#                                 classification_results  \
# 304  ([programmatic representation, accountability ...
# 306  ([accountability and transparency, programmati...
# 320  ([programmatic representation, accountability ...
# 324  ([accountability and transparency, clientelist...
# 325  ([development, accountability and transparency...
#
#                         top_category  top_category_score
# 304      programmatic representation            0.769578
# 306  accountability and transparency            0.614412
# 320      programmatic representation            0.874857
# 324  accountability and transparency            0.433297
# 325                      development            0.952534
#
# [5 rows x 68 columns]

# %%
df_merged_final['classification_results'][304]
# Out:
# (['programmatic representation',
#   'accountability and transparency',
#   'clientelistic representation',
#   'development',
#   'corruption'],
#  [0.7695783376693726,
#   0.6634148359298706,
#   0.2397715002298355,
#   0.19319695234298706,
#   0.018497761338949203])

# %%
df_merged_final = df_merged_final.drop(columns=['link', 'TCPD_Prof_Main', 'TCPD_Prof_Main_Desc', 'TCPD_Prof_Second',
                                    'TCPD_Prof_Second_Desc', 'Election_Type', 'MyNeta_education',
                                    'Recontest', 'Incumbent', 'Turncoat', 'No_Terms', 'Same_Party',
                                    'Same_Constituency', 'Last_Constituency_Name', 'Last_Party_ID',
                                    'Last_Party', 'Contested', 'last_poll', 'Party_ID', 'Party_Type_TCPD',
                                    'pid', 'ENOP', 'Year_x'
                                    ])

# %%
df_merged_final.rename(columns={"Year_y": "Year"})
# Out:
#              id       date ls_number  \
# 304    17350913 1999-12-09        13
# 306    17354313 1999-12-01        13
# 320    17353813 1999-12-02        13
# 324    10021313 2004-02-04        13
# 325    16344514 2004-08-16        14
# ...         ...        ...       ...
# 35059  14598216 2014-12-22        16
# 35060  14566316 2014-12-23        16
# 35061  15517516 2014-07-21        16
# 35074  15030816 2014-11-27        16
# 35075  15622016 2014-07-15        16
#
#                                                 ministry question_type  \
# 304                                    Rural Development     Unstarred
# 306                                       Prime Minister     Unstarred
# 320                                    Rural Development     Unstarred
# 324                                             Shipping     Unstarred
# 325                                              Tourism     Unstarred
# ...                                                  ...           ...
# 35059                                           Railways     Unstarred
# 35060            Environment, Forests and Climate Change     Unstarred
# 35061                                              Mines     Unstarred
# 35074  Water Resources, River Development and Ganaga ...     Unstarred
# 35075  Skill Development, Entrepreneurship,youth Affa...     Unstarred
#
#                                            question_text  \
# 304    (a) whether any scheme is under consideation o...
# 306    (a) whether the Government propose to conduct ...
# 320    (a) The guidelines and directions issued by th...
# 324    (a) the time when the Sompen Hospital Ship arr...
# 325    (a) whether the Government has any proposal to...
# ...                                                  ...
# 35059  (a) whether the employees of Railways are cove...
# 35060  (a) whether deforestation/felling of trees is ...
# 35061  (a) the details of steps taken by the Governme...
# 35074  (a) whether the Government is aware that five ...
# 35075  (a) whether the Government proposes to promote...
#
#                                              answer_text  \
# 304    MINISTER OF STATE FOR RURAL DEVELOPMENT (SHRI ...
# 306    THE MINISTER OF STATE IN THE DEPARTMENT OF ATO...
# 320    Minister of State for RURAL DEVELOPMENT (SHRI ...
# 324    MINISTER OF STATE IN THE MINISTRY OF SHIPPING ...
# 325    MINISTER OF STATE FOR TOURISM (INDEPENDENT CHA...
# ...                                                  ...
# 35059  MINISTER OF STATE IN THE MINISTRY OF RAILWAYS ...
# 35060  MINISTER OF STATE (INDEPENDENT CHARGE) FOR ENV...
# 35061  THE MINISTER OF STATE FOR MINES, STEEL AND LAB...
# 35074  THE MINISTER OF STATE FOR WATER RESOURCES, RIV...
# 35075  THE MINISTER OF STATE (INDEPENDENT CHARGE) FOR...
#
#                      member party                      state  ...  \
# 304    ABDUL RASHID SHAHEEN   JKN            Jammu & Kashmir  ...
# 306             T. GOVINDAN   CPM                     Kerala  ...
# 320         SAMAR CHOWDHURY   CPM                    Tripura  ...
# 324         BISHNU PADA RAY   BJP  Andaman & Nicobar Islands  ...
# 325       MANORANJAN BHAKTA   INC  Andaman & Nicobar Islands  ...
# ...                     ...   ...                        ...  ...
# 35059  ANUPRIYA SINGH PATEL    AD              Uttar Pradesh  ...
# 35060  ANUPRIYA SINGH PATEL    AD              Uttar Pradesh  ...
# 35061  ANUPRIYA SINGH PATEL    AD              Uttar Pradesh  ...
# 35074             CHHOTELAL   BJP              Uttar Pradesh  ...
# 35075             CHHOTELAL   BJP              Uttar Pradesh  ...
#
#       Turnout_Percentage Vote_Share_Percentage Deposit_Lost    Margin  \
# 304                25.11                 43.94           no   36113.0
# 306                77.12                 45.77           no   31578.0
# 320                68.88                 57.46           no  198399.0
# 324                63.66                 55.77           no   30500.0
# 325                63.66                 55.77           no   30500.0
# ...                  ...                   ...          ...       ...
# 35059              58.56                 43.32           no  219079.0
# 35060              58.56                 43.32           no  219079.0
# 35061              58.56                 43.32           no  219079.0
# 35074              54.05                 42.69           no  190486.0
# 35075              54.05                 42.69           no  190486.0
#
#       Margin_Percentage previous_sex gender_change  \
# 304               18.83            M         False
# 306                3.41            M         False
# 320               30.60            M         False
# 324               19.83            M         False
# 325               19.83            M         False
# ...                 ...          ...           ...
# 35059             21.74            M          True
# 35060             21.74            M          True
# 35061             21.74            M          True
# 35074             21.50            M         False
# 35075             21.50            M         False
#
#                                   classification_results  \
# 304    ([programmatic representation, accountability ...
# 306    ([accountability and transparency, programmati...
# 320    ([programmatic representation, accountability ...
# 324    ([accountability and transparency, clientelist...
# 325    ([development, accountability and transparency...
# ...                                                  ...
# 35059  ([accountability and transparency, programmati...
# 35060  ([programmatic representation, accountability ...
# 35061  ([accountability and transparency, programmati...
# 35074  ([accountability and transparency, programmati...
# 35075  ([accountability and transparency, programmati...
#
#                           top_category  top_category_score
# 304        programmatic representation            0.769578
# 306    accountability and transparency            0.614412
# 320        programmatic representation            0.874857
# 324    accountability and transparency            0.433297
# 325                        development            0.952534
# ...                                ...                 ...
# 35059  accountability and transparency            0.750319
# 35060      programmatic representation            0.366077
# 35061  accountability and transparency            0.795397
# 35074  accountability and transparency            0.905049
# 35075  accountability and transparency            0.840686
#
# [28543 rows x 45 columns]

# %%
# cleaning up results

def process_classification_results(row):
    if isinstance(row, str):
        labels, scores = ast.literal_eval(row)
    else:
        labels, scores = row

    # dictionary with labels as keys and scores as values
    return dict(zip(labels, scores))

# %%
# putting the function to the 'classification_results' column
df_merged_final['processed_results'] = df_merged_final['classification_results'].apply(process_classification_results)

# %%
# separate columns for each classification result
classification_labels = ['programmatic representation', 'accountability and transparency', 'clientelistic representation', 'development', 'corruption']

for label in classification_labels:
    df_merged_final[label + '_score'] = df_merged_final['processed_results'].apply(lambda x: x.get(label, None))

# %%
df_merged_final.head()
# Out:
#            id       date ls_number           ministry question_type  \
# 304  17350913 1999-12-09        13  Rural Development     Unstarred
# 306  17354313 1999-12-01        13     Prime Minister     Unstarred
# 320  17353813 1999-12-02        13  Rural Development     Unstarred
# 324  10021313 2004-02-04        13           Shipping     Unstarred
# 325  16344514 2004-08-16        14            Tourism     Unstarred
#
#                                          question_text  \
# 304  (a) whether any scheme is under consideation o...
# 306  (a) whether the Government propose to conduct ...
# 320  (a) The guidelines and directions issued by th...
# 324  (a) the time when the Sompen Hospital Ship arr...
# 325  (a) whether the Government has any proposal to...
#
#                                            answer_text                member  \
# 304  MINISTER OF STATE FOR RURAL DEVELOPMENT (SHRI ...  ABDUL RASHID SHAHEEN
# 306  THE MINISTER OF STATE IN THE DEPARTMENT OF ATO...           T. GOVINDAN
# 320  Minister of State for RURAL DEVELOPMENT (SHRI ...       SAMAR CHOWDHURY
# 324  MINISTER OF STATE IN THE MINISTRY OF SHIPPING ...       BISHNU PADA RAY
# 325  MINISTER OF STATE FOR TOURISM (INDEPENDENT CHA...     MANORANJAN BHAKTA
#
#     party                      state  ... gender_change  \
# 304   JKN            Jammu & Kashmir  ...         False
# 306   CPM                     Kerala  ...         False
# 320   CPM                    Tripura  ...         False
# 324   BJP  Andaman & Nicobar Islands  ...         False
# 325   INC  Andaman & Nicobar Islands  ...         False
#
#                                 classification_results  \
# 304  ([programmatic representation, accountability ...
# 306  ([accountability and transparency, programmati...
# 320  ([programmatic representation, accountability ...
# 324  ([accountability and transparency, clientelist...
# 325  ([development, accountability and transparency...
#
#                         top_category top_category_score  \
# 304      programmatic representation           0.769578
# 306  accountability and transparency           0.614412
# 320      programmatic representation           0.874857
# 324  accountability and transparency           0.433297
# 325                      development           0.952534
#
#                                      processed_results development_score  \
# 304  {'programmatic representation': 0.769578337669...          0.193197
# 306  {'accountability and transparency': 0.61441200...          0.259336
# 320  {'programmatic representation': 0.874856531620...          0.505724
# 324  {'accountability and transparency': 0.43329674...          0.021046
# 325  {'development': 0.9525343775749207, 'accountab...          0.952534
#
#     corruption_score  programmatic representation_score  \
# 304         0.018498                           0.769578
# 306         0.003222                           0.410504
# 320         0.005591                           0.874857
# 324         0.005672                           0.187835
# 325         0.007300                           0.682238
#
#      accountability and transparency_score  clientelistic representation_score
# 304                               0.663415                            0.239772
# 306                               0.614412                            0.292619
# 320                               0.855427                            0.305820
# 324                               0.433297                            0.340559
# 325                               0.901977                            0.583766
#
# [5 rows x 51 columns]

# %%
df_merged_final = df_merged_final.drop(columns=['programmatic_representation_score', 'accountability_and_transparency_score',
                                                'clientelistic_representation_score',
                     ])

# %%
df_merged_final.to_csv('dataset_final.csv', index=False)
